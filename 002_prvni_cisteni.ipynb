# %%
import polars as pl

# %%
cesta = 'downloads/popes'

# %%
import os

# %%
import json

# %%
ktery = os.listdir(cesta)[3]
ktery = 'Q450675_Pope_Francis.json'

# %%
with open(os.path.join(cesta, ktery), 'r', encoding='utf-8') as papez:
    papez = json.loads(papez.read())

# %%
papez['entities'][list(papez['entities'])[0]]
# Out:
# {'pageid': 104710,
#  'ns': 0,
#  'title': 'Q102105',
#  'lastrevid': 2340561931,
#  'modified': '2025-04-22T11:01:49Z',
#  'type': 'item',
#  'id': 'Q102105',
#  'labels': {'zh-hans': {'language': 'zh-hans', 'value': '教宗利伯略'},
#   'zh-hant': {'language': 'zh-hant', 'value': '教宗利伯略'},
#   'zh-hk': {'language': 'zh-hk', 'value': '教宗利伯略'},
#   'zh-cn': {'language': 'zh-cn', 'value': '教宗利伯略'},
#   'zh-sg': {'language': 'zh-sg', 'value': '教宗利伯略'},
#   'zh-tw': {'language': 'zh-tw', 'value': '教宗利伯略'},
#   'jv': {'language': 'jv', 'value': 'Paus Liberius'},
#   'pl': {'language': 'pl', 'value': 'Liberiusz'},
#   'eu': {'language': 'eu', 'value': 'Liberio'},
#   'es': {'language': 'es', 'value': 'Liberio'},
#   'ta': {'language': 'ta', 'value': 'லிபேரியஸ்'},
#   'af': {'language': 'af', 'value': 'Pous Liberius'},
#   'hu': {'language': 'hu', 'value': 'Libériusz pápa'},
#   'ceb': {'language': 'ceb', 'value': 'Liberio'},
#   'sw': {'language': 'sw', 'value': 'Papa Liberius'},
#   'et': {'language': 'et', 'value': 'Liberius'},
#   'br': {'language': 'br', 'value': 'Liberius'},
#   'el': {'language': 'el', 'value': 'Πάπας Λιβέριος'},
#   'ar': {'language': 'ar', 'value': 'ليبيريوس'},
#   'sv': {'language': 'sv', 'value': 'Liberius'},
#   'nl': {'language': 'nl', 'value': 'Paus Liberius'},
#   'pt': {'language': 'pt', 'value': 'Papa Libério'},
#   'eo': {'language': 'eo', 'value': 'Libero'},
#   'ru': {'language': 'ru', 'value': 'Либерий'},
#   'mk': {'language': 'mk', 'value': 'Папа Либериј'},
#   'fi': {'language': 'fi', 'value': 'Liberius'},
#   'uk': {'language': 'uk', 'value': 'Ліберій'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'Лібэрыюс'},
#   'mzn': {'language': 'mzn', 'value': 'لیبریوس'},
#   'hr': {'language': 'hr', 'value': 'Liberije'},
#   'tl': {'language': 'tl', 'value': 'Liberio'},
#   'da': {'language': 'da', 'value': 'Pave Liberius 1.'},
#   'be': {'language': 'be', 'value': 'Ліберый, Папа Рымскі'},
#   'ko': {'language': 'ko', 'value': '교황 리베리오'},
#   'arz': {'language': 'arz', 'value': 'القديس ليبيريوس'},
#   'he': {'language': 'he', 'value': 'ליבריוס'},
#   'fr': {'language': 'fr', 'value': 'Libère'},
#   'yo': {'language': 'yo', 'value': 'Pópù Liberius'},
#   'it': {'language': 'it', 'value': 'papa Liberio'},
#   'gl': {'language': 'gl', 'value': 'Liberio'},
#   'id': {'language': 'id', 'value': 'Paus Liberius'},
#   'de': {'language': 'de', 'value': 'Liberius'},
#   'ja': {'language': 'ja', 'value': 'リベリウス'},
#   'vi': {'language': 'vi', 'value': 'Giáo hoàng Libêrô'},
#   'sh': {'language': 'sh', 'value': 'Papa Liberije'},
#   'sk': {'language': 'sk', 'value': 'Libérius'},
#   'en': {'language': 'en', 'value': 'Liberius'},
#   'th': {'language': 'th', 'value': 'สมเด็จพระสันตะปาปาลิเบอริอุส'},
#   'ro': {'language': 'ro', 'value': 'Papa Liberiu'},
#   'ca': {'language': 'ca', 'value': 'Liberi'},
#   'la': {'language': 'la', 'value': 'Liberius'},
#   'sl': {'language': 'sl', 'value': 'Papež Liberij'},
#   'war': {'language': 'war', 'value': 'Papa Liberio'},
#   'cs': {'language': 'cs', 'value': 'Liberius'},
#   'fa': {'language': 'fa', 'value': 'لیبریوس'},
#   'mr': {'language': 'mr', 'value': 'पोप लायबेरियस'},
#   'bg': {'language': 'bg', 'value': 'Либерий'},
#   'ka': {'language': 'ka', 'value': 'ლიბერიუსი'},
#   'nds': {'language': 'nds', 'value': 'Liberius'},
#   'ilo': {'language': 'ilo', 'value': 'Papa Liberio'},
#   'zh': {'language': 'zh', 'value': '教宗利伯略'},
#   'sq': {'language': 'sq', 'value': 'Papa Liberi'},
#   'nb': {'language': 'nb', 'value': 'Liberius'},
#   'oc': {'language': 'oc', 'value': 'Libèri'},
#   'sr': {'language': 'sr', 'value': 'Папа Либерије'},
#   'yue': {'language': 'yue', 'value': '立柏'},
#   'ga': {'language': 'ga', 'value': 'Pápa Liberius'},
#   'hak': {'language': 'hak', 'value': 'Kau-fòng Liberius'},
#   'nan': {'language': 'nan', 'value': 'Kàu-hông Liberius'},
#   'cdo': {'language': 'cdo', 'value': 'Gáu-huòng Liberius'},
#   'lv': {'language': 'lv', 'value': 'Libērijs'},
#   'tr': {'language': 'tr', 'value': 'Liberius'},
#   'ast': {'language': 'ast', 'value': 'Papa Liberiu'},
#   'hy': {'language': 'hy', 'value': 'Լիբերիոս (Հռոմի պապ)'},
#   'gsw': {'language': 'gsw', 'value': 'Liberius (Bischof von Rom)'},
#   'mg': {'language': 'mg', 'value': 'Liberio (papa)'},
#   'wuu': {'language': 'wuu', 'value': '教宗利伯略'},
#   'diq': {'language': 'diq', 'value': 'Liberius'},
#   'pt-br': {'language': 'pt-br', 'value': 'Papa Libério'},
#   'io': {'language': 'io', 'value': 'Papo Liberius'},
#   'ms': {'language': 'ms', 'value': 'Paus Liberius'},
#   'nn': {'language': 'nn', 'value': 'Liberius'},
#   'ur': {'language': 'ur', 'value': 'لیبیریوس'}},
#  'descriptions': {'fr': {'language': 'fr', 'value': 'évêque de Rome'},
#   'hu': {'language': 'hu', 'value': 'a 36. pápa'},
#   'ilo': {'language': 'ilo', 'value': 'Papa ti Katoliko a Simbaan'},
#   'en': {'language': 'en',
#    'value': 'Head of the Catholic Church from 352 to 366'},
#   'de': {'language': 'de', 'value': 'Papst'},
#   'hr': {'language': 'hr', 'value': 'papa'},
#   'pl': {'language': 'pl', 'value': 'papież z IV wieku, święty prawosławny'},
#   'it': {'language': 'it',
#    'value': '36° vescovo di Roma e papa della Chiesa cattolica dal 352 al 366'},
#   'es': {'language': 'es', 'value': '36° Papa de la Iglesia Católica'},
#   'lv': {'language': 'lv', 'value': 'Romas pāvests no 352. līdz 366. gadam'},
#   'zh': {'language': 'zh', 'value': '羅馬天主教會第36任教宗'},
#   'ru': {'language': 'ru', 'value': 'папа римский'},
#   'he': {'language': 'he', 'value': 'האפיפיור ה-36, בין השנים 352-366.'},
#   'sv': {'language': 'sv',
#    'value': 'Påve år 352—366 och helgon i romersk-katolska kyrkan'},
#   'dv': {'language': 'dv', 'value': 'ލިޔުންތެރިއެއް'},
#   'ga': {'language': 'ga', 'value': 'pápa'},
#   'ar': {'language': 'ar', 'value': 'بابا'},
#   'sr': {'language': 'sr', 'value': 'поглавар Римокатоличке цркве'},
#   'cs': {'language': 'cs', 'value': 'papež'},
#   'ta': {'language': 'ta', 'value': '4ஆம் நூற்றாண்டு திருத்தந்தை'},
#   'eo': {'language': 'eo', 'value': 'papo de la katolika eklezio'},
#   'ca': {'language': 'ca', 'value': "papa de l'església catòlica"},
#   'fi': {'language': 'fi', 'value': 'paavi'},
#   'id': {'language': 'id',
#    'value': 'Paus Gereja Katolik dari tahun 352 hingga 366'}},
#  'aliases': {'pl': [{'language': 'pl', 'value': 'Papież Liberiusz'}],
#   'es': [{'language': 'es', 'value': 'San Liberio'},
#    {'language': 'es', 'value': 'Liberio I'}],
#   'ceb': [{'language': 'ceb', 'value': 'Papa Liberio'}],
#   'pt': [{'language': 'pt', 'value': 'São libério'}],
#   'ru': [{'language': 'ru', 'value': 'Либерий I'},
#    {'language': 'ru', 'value': 'Ливерий Исповедник'}],
#   'be-tarask': [{'language': 'be-tarask', 'value': 'Лібэры'}],
#   'da': [{'language': 'da', 'value': 'Pave Liberius'}],
#   'fr': [{'language': 'fr', 'value': 'Liberus'},
#    {'language': 'fr', 'value': 'Libere'}],
#   'yo': [{'language': 'yo', 'value': 'Pope Liberius'}],
#   'vi': [{'language': 'vi', 'value': 'Liberius'},
#    {'language': 'vi', 'value': 'Libêrô'}],
#   'sh': [{'language': 'sh', 'value': 'Liberije'}],
#   'ro': [{'language': 'ro', 'value': 'Liberiu'}],
#   'war': [{'language': 'war', 'value': 'Pope Liberius'}],
#   'fa': [{'language': 'fa', 'value': 'پاپ لیبریوس'}],
#   'en': [{'language': 'en', 'value': 'Pope Liberius'}],
#   'be': [{'language': 'be', 'value': 'Папа Рымскі Ліберый'}],
#   'la': [{'language': 'la', 'value': 'Liberius Papa'}],
#   'oc': [{'language': 'oc', 'value': 'Libèr'}]},
#  'claims': {'P21': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P21',
#      'hash': '85ad4b1c7348f7a5aac521135040d74e91fb5939',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 6581097,
#        'id': 'Q6581097'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'q102105$9937E5BF-21E0-46F6-9936-B13BDA1188B5',
#     'rank': 'normal',
#     'references': [{'hash': 'bd49d3e4f67bc460ce7a06b6ac3027347cf5ee55',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e84b0343e79e2a9aa8abadd7301051e15fba52d6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 169514,
#            'id': 'Q169514'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']},
#      {'hash': 'd5847b9b6032aa8b13dae3c2dfd9ed5d114d21b3',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '5a343e7e758a4282a01316d3e959b6e653b767fc',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 11920,
#            'id': 'Q11920'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P39': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P39',
#      'hash': '36130f50ca28aaa85722f6edc0a5ee719014e50b',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 19546,
#        'id': 'Q19546'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P580': [{'snaktype': 'value',
#        'property': 'P580',
#        'hash': '2e0c646cd506fb602ff66d6d6edb630e8dd3d830',
#        'datavalue': {'value': {'time': '+0352-05-17T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P582': [{'snaktype': 'value',
#        'property': 'P582',
#        'hash': 'b159a1bea2d554ff90560dbb1baf3114f25a73ee',
#        'datavalue': {'value': {'time': '+0366-09-24T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#         'type': 'time'},
#        'datatype': 'time'}],
#      'P1365': [{'snaktype': 'value',
#        'property': 'P1365',
#        'hash': 'a1bc520004cf2bf780348629474b5ec923234888',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 103101,
#          'id': 'Q103101'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}],
#      'P1366': [{'snaktype': 'value',
#        'property': 'P1366',
#        'hash': '3e502c6b76aeafea07c25948669408555b265785',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 130997,
#          'id': 'Q130997'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}],
#      'P1545': [{'snaktype': 'value',
#        'property': 'P1545',
#        'hash': 'a5a17d924a943d498c302ff429c1a0b52fc17de4',
#        'datavalue': {'value': '36', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P580', 'P582', 'P1365', 'P1366', 'P1545'],
#     'id': 'q102105$F8F2431B-1C3E-48AA-8D81-79003B686516',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P373': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P373',
#      'hash': '329f9af4bab369eed221414db9460713a739a132',
#      'datavalue': {'value': 'Liberius', 'type': 'string'},
#      'datatype': 'string'},
#     'type': 'statement',
#     'id': 'q102105$3422A727-28A2-4711-ACDD-A152F3E759E9',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P214': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P214',
#      'hash': '3a89acbdf634a62b29f9857a1a09887af0beea82',
#      'datavalue': {'value': '58662922', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q102105$BD2CAE3C-18A6-4DCC-BF0E-55944BDE8232',
#     'rank': 'normal',
#     'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 48183,
#            'id': 'Q48183'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P214',
#      'hash': '4ae84a10f4e374a73691b437833f6104b0e66a7b',
#      'datavalue': {'value': '217159474192727661973', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$e9bb16a6-4b5e-2d25-8682-3bf3005b8495',
#     'rank': 'normal'}],
#   'P227': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P227',
#      'hash': '79c3581d88a433d63731e3cc2d00a5855e2895bc',
#      'datavalue': {'value': '118779869', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q102105$18C3F548-3548-47E1-B549-9094F75F1BB0',
#     'rank': 'normal',
#     'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 48183,
#            'id': 'Q48183'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P213': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P213',
#      'hash': 'da6ac98eabd8a3d1908cfa9b0f4b871aed6f3bf9',
#      'datavalue': {'value': '0000000078581619', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$FAB808BE-85C3-466A-A015-D193E41E8418',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P213',
#      'hash': '60e35a32be3ea877d7ed34222c4efc3f9c56b27f',
#      'datavalue': {'value': '0000000388886178', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$089c9502-494f-dd0c-616e-21451fe4f41a',
#     'rank': 'normal'}],
#   'P569': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P569',
#      'hash': '3773f903168c92d396deef18c6e3742eb93d4c98',
#      'datavalue': {'value': {'time': '+0310-00-00T00:00:00Z',
#        'timezone': 0,
#        'before': 0,
#        'after': 0,
#        'precision': 9,
#        'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#       'type': 'time'},
#      'datatype': 'time'},
#     'type': 'statement',
#     'qualifiers': {'P1480': [{'snaktype': 'value',
#        'property': 'P1480',
#        'hash': 'cb40f2027a88b8d23735681aaccba1069a574f54',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5727902,
#          'id': 'Q5727902'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P1480'],
#     'id': 'q102105$13009a9f-44c9-8473-7463-4fc258367868',
#     'rank': 'normal'}],
#   'P570': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P570',
#      'hash': '771b110916402466168438fae6cd55f7702b870c',
#      'datavalue': {'value': {'time': '+0366-09-24T00:00:00Z',
#        'timezone': 0,
#        'before': 0,
#        'after': 0,
#        'precision': 11,
#        'calendarmodel': 'http://www.wikidata.org/entity/Q1985786'},
#       'type': 'time'},
#      'datatype': 'time'},
#     'type': 'statement',
#     'id': 'q102105$2c4fc2ab-4ed6-ddca-3881-4a0adf42bdbd',
#     'rank': 'normal'}],
#   'P31': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P31',
#      'hash': 'ad7d38a03cdd40cdc373de0dc4e7b7fcbccb31d9',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 5,
#        'id': 'Q5'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$5CD4E5F1-5F7B-4526-B5E6-599959923687',
#     'rank': 'normal',
#     'references': [{'hash': '27c17a78409b09e11275406341793fd03c6adebe',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '3bd60302f69c76cfc7f921f119a778bdff18496f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3892772,
#            'id': 'Q3892772'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P1047': [{'snaktype': 'value',
#          'property': 'P1047',
#          'hash': 'c91fc73fa9d369c616706141ec791f1985170b2f',
#          'datavalue': {'value': 'liberius', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'a06e365984010e40523acaef7303246501814b09',
#          'datavalue': {'value': {'time': '+2020-10-29T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P1047', 'P813']}]}],
#   'P646': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P646',
#      'hash': 'af7b9b2ef18919d2c6eb27c5140098622fc18d1b',
#      'datavalue': {'value': '/m/0f4tl', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$D5527507-C956-416B-9AB5-212560042699',
#     'rank': 'normal',
#     'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 15241312,
#            'id': 'Q15241312'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P577': [{'snaktype': 'value',
#          'property': 'P577',
#          'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#          'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P577']}]}],
#   'P244': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P244',
#      'hash': 'fb463bf4063e242372e0eebcddbef4ab4b958f6e',
#      'datavalue': {'value': 'no95025028', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$11CC3ADD-F9D8-4418-BE50-8E6142FB179E',
#     'rank': 'normal',
#     'references': [{'hash': '0baf8d443a1712c02288a05db56741837b50df0f',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '3f633946e6f6e9290f6dd6c59411e04b6d53a673',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8563685,
#            'id': 'Q8563685'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P18': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P18',
#      'hash': '9af78793a1bab99d9b3e36705c30fbc9425e4662',
#      'datavalue': {'value': 'Liberio papa1.gif', 'type': 'string'},
#      'datatype': 'commonsMedia'},
#     'type': 'statement',
#     'id': 'Q102105$E71F6A22-EF3F-4CE8-A7E6-F728EADF63A3',
#     'rank': 'normal',
#     'references': [{'hash': 'd4bd87b862b12d99d26e86472d44f26858dee639',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8447,
#            'id': 'Q8447'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P140': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P140',
#      'hash': 'd2c9eca604ede83ae9ca9fc525294f8456fbb5dd',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 9592,
#        'id': 'Q9592'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$D6265E8A-F7CF-4771-ACC8-CDE200A3CCBB',
#     'rank': 'normal',
#     'references': [{'hash': '4a229b6cab84ce3bbde5b2aeb551dfc89847e027',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '3bd60302f69c76cfc7f921f119a778bdff18496f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3892772,
#            'id': 'Q3892772'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P1047': [{'snaktype': 'value',
#          'property': 'P1047',
#          'hash': 'c91fc73fa9d369c616706141ec791f1985170b2f',
#          'datavalue': {'value': 'liberius', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '9d9044193304c6daabb1a7fd9b0050defc2e4b1c',
#          'datavalue': {'value': {'time': '+2020-10-22T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P1047', 'P813']}]}],
#   'P1343': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1343',
#      'hash': '8162cca1bad1bd4a401fa1c7c67f2d8593a9a9c0',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 678259,
#        'id': 'Q678259'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$15CA5B05-FEA2-4EA1-8ABF-9801FC570139',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1343',
#      'hash': '5b0ef3d5413cd39d887fbe70d2d3b3f4a94ea9d8',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1138524,
#        'id': 'Q1138524'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P805': [{'snaktype': 'value',
#        'property': 'P805',
#        'hash': '4a768268a279c72ce9542509ed7ad42bd06d987b',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 20872935,
#          'id': 'Q20872935'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P805'],
#     'id': 'Q102105$02578C55-938E-477E-BEAD-860523D551EE',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1343',
#      'hash': '88389772f86dcd7d415ddd029f601412e5cc894a',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 602358,
#        'id': 'Q602358'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P805': [{'snaktype': 'value',
#        'property': 'P805',
#        'hash': 'f73a3784fad8c9377ba4c5678b1730fab17b584f',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 24458938,
#          'id': 'Q24458938'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P805'],
#     'id': 'Q102105$853d18a5-4e36-ef81-0ee5-b25c15a5c53c',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1343',
#      'hash': '42346dfe9209b7359c1f5db829a368b38d407797',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 19180675,
#        'id': 'Q19180675'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P805': [{'snaktype': 'value',
#        'property': 'P805',
#        'hash': '8b24526d50485d6485fd006e1b999675dec21753',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 24760052,
#          'id': 'Q24760052'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P805'],
#     'id': 'Q102105$424d2a0b-47ff-e91c-9a63-c40be57ffcdd',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P1343',
#      'hash': '1e87e0f7d2db06ab0ef5ccabd7c6275641f36553',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 867541,
#        'id': 'Q867541'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P805': [{'snaktype': 'value',
#        'property': 'P805',
#        'hash': '2d2731a3daaf4bfab23051f4f5df07421ed60272',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 84650830,
#          'id': 'Q84650830'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P805'],
#     'id': 'Q102105$D3D6A928-D008-4809-AF85-EEA70AF8AF6B',
#     'rank': 'normal'}],
#   'P20': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P20',
#      'hash': 'abce19191288d59144164df0359d6e6000e9f8ce',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 220,
#        'id': 'Q220'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$a6ba5183-ed97-4a67-8629-07bb95b5f299',
#     'rank': 'normal',
#     'references': [{'hash': '2e7fa0083ba1c302cdcf3fa65c613f90daeb4c37',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '5a6fb73df37ac546825b07ebb80a22de88d99425',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 58255,
#            'id': 'Q58255'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P1296': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1296',
#      'hash': 'e01c4294a6ca444cf8938feab03505a24bb85c01',
#      'datavalue': {'value': '0037155', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$5C5490DF-0D5D-4355-94C0-E8A49D662434',
#     'rank': 'normal'}],
#   'P1422': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1422',
#      'hash': '9f0e2acec3e06658a3670a3a29df873a5c8201d1',
#      'datavalue': {'value': '254', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$5AB42F88-EC8B-453E-92EB-A6AD15F1CB0E',
#     'rank': 'normal'}],
#   'P411': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P411',
#      'hash': '15684741df9a5db613e851b5157a05acdbf340c9',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 3464126,
#        'id': 'Q3464126'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$B4E97175-1966-45C9-9EE0-9C296ACAAE1E',
#     'rank': 'normal'}],
#   'P1871': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1871',
#      'hash': '3ef70947a7b0bad3e4e9b1d56be84c2ad39f69f1',
#      'datavalue': {'value': 'cnp00588533', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$18AC6EF1-CA97-49D1-B087-86006ABFEDEC',
#     'rank': 'normal',
#     'references': [{'hash': '2cd3b591566a5413c581c7ee3a0eb13685850adf',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'b6067d1f9610c88660b5cf521f62ca61de64bf3b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 60909659,
#            'id': 'Q60909659'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P106': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': 'e3b51e796019773a0a66427b08dd4a904404f3df',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 250867,
#        'id': 'Q250867'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$404DED4E-6DC7-4436-BA06-DA4E1D1F1132',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '70541c2eb72d85fa5f74008b4ee33b004a1ff7eb',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 36180,
#        'id': 'Q36180'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$479A150C-DF58-49C7-93D9-6AB65F9D5B12',
#     'rank': 'normal',
#     'references': [{'hash': '7866baa1d2a4db2b7f60b6a8170ce8b8f1a580e9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'c2a7f0b4dc0307860e8728285e84ec8779559b6a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 85135665,
#            'id': 'Q85135665'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P19': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P19',
#      'hash': '22bf7e0895b36002ce756914f81306954a921739',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 220,
#        'id': 'Q220'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P17': [{'snaktype': 'value',
#        'property': 'P17',
#        'hash': '7bb9bb285193e8899cda557f57ba865835912189',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 2277,
#          'id': 'Q2277'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'}]},
#     'qualifiers-order': ['P17'],
#     'id': 'Q102105$2ED83DCB-CB52-4F06-BA85-CD5F9007DC72',
#     'rank': 'normal',
#     'references': [{'hash': '4e3b6085ba71dbe3e5af1b11069d6adf4add8337',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '6aec36b0f3f3f22e2cad1960679c8e61779cbd29',
#          'datavalue': {'value': 'https://www.catholic.org/saints/saint.php?saint_id=1010',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P854']}]}],
#   'P2348': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2348',
#      'hash': 'bf2960d9b69dc3388e9ff10e3d470cf3b6727008',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 2277,
#        'id': 'Q2277'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$FE5D0ED4-F5B2-4513-B7B7-CA953D190260',
#     'rank': 'normal'}],
#   'P3241': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P3241',
#      'hash': '0007c2c7e3f3873b80cecb2320c1bab1dff21e43',
#      'datavalue': {'value': '09217a', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$4C2B9C7E-976B-49BC-AF58-65BAF7E3ADD5',
#     'rank': 'normal'}],
#   'P1417': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1417',
#      'hash': '5bcd94f541e05fc8790c52f9e4f2d52d5ad3b410',
#      'datavalue': {'value': 'biography/Liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': 'b5e230f4a3c90417105c6a2162af5673e2dfb527',
#        'datavalue': {'value': 'Liberius', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q102105$952240F1-FADE-402F-8A53-473461EAFC83',
#     'rank': 'normal'}],
#   'P841': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P841',
#      'hash': 'aca2a9e6b2b8e73078b2173d511335e75071e21a',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 2822,
#        'id': 'Q2822'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$11537251-9E80-4DDC-B7F9-0AEC9C0F7C04',
#     'rank': 'normal',
#     'references': [{'hash': '3bf39867b037e8e494a8389ae8a03bad6825a7fc',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '5946b91c53409c48f5f1fb0319ed41fc67a764da',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 191168,
#            'id': 'Q191168'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P937': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P937',
#      'hash': '31e515f6b42ff6b7a2ecd01b0fb9dd82b9987a2d',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 220,
#        'id': 'Q220'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$711F4F8B-34EF-4084-8864-6007EB866479',
#     'rank': 'normal',
#     'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 328,
#            'id': 'Q328'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]}],
#   'P4286': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4286',
#      'hash': 'd129388de2f634f07233fb6750cb27fe178c1727',
#      'datavalue': {'value': '8321/Libere', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$C60811E1-62E4-4581-8D26-B64AC8F4055D',
#     'rank': 'normal'}],
#   'P1280': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1280',
#      'hash': '25d091ab3302dc281cb429bc4ac93ffb0822b1b9',
#      'datavalue': {'value': '197543779', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'qualifiers': {'P1810': [{'snaktype': 'value',
#        'property': 'P1810',
#        'hash': '19cc3d107aba6efe943bb08a7cdf3ddac574e013',
#        'datavalue': {'value': 'Liberius, Pope, ?-366', 'type': 'string'},
#        'datatype': 'string'}]},
#     'qualifiers-order': ['P1810'],
#     'id': 'Q102105$D492B32A-D845-4854-AB42-909D437C1C1A',
#     'rank': 'normal'}],
#   'P7935': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7935',
#      'hash': 'a29622fdccd29ff4197b069789368b4189517473',
#      'datavalue': {'value': 'Liberius_papa', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$47F5AEE4-D1E1-449F-8C55-5935DF0B6759',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P7935',
#      'hash': '57eb9a13fbecb7eec054b0c7f333ba5e37282270',
#      'datavalue': {'value': 'Liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$613785A6-BB84-4EDC-808C-0C840E1D9ECE',
#     'rank': 'normal'}],
#   'P1412': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1412',
#      'hash': 'b5b2b8af4e7146bb59f179efccb54664236b13c0',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 397,
#        'id': 'Q397'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q102105$EE6ECD89-2D31-4914-9E76-C18C4F208D78',
#     'rank': 'normal',
#     'references': [{'hash': '7866baa1d2a4db2b7f60b6a8170ce8b8f1a580e9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'c2a7f0b4dc0307860e8728285e84ec8779559b6a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 85135665,
#            'id': 'Q85135665'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P7986': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7986',
#      'hash': '742ee586c585284f9dbb2ddecc484556596b15ba',
#      'datavalue': {'value': '42422', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$8D2FC9EB-87A5-4013-9D5D-12163224472D',
#     'rank': 'normal',
#     'references': [{'hash': '7866baa1d2a4db2b7f60b6a8170ce8b8f1a580e9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'c2a7f0b4dc0307860e8728285e84ec8779559b6a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 85135665,
#            'id': 'Q85135665'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P248']}]}],
#   'P2163': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P2163',
#      'hash': '6a039377a73459aaede574b2235875da0d8ae647',
#      'datavalue': {'value': '1830843', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$B0507A72-5973-4354-A836-FCC4D62A5709',
#     'rank': 'normal',
#     'references': [{'hash': '803daa98c8dd64325aa0eba9edaef56cd3e92554',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'c120f07504c77593a9d734f50361ea829f601960',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 620946,
#            'id': 'Q620946'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P244': [{'snaktype': 'value',
#          'property': 'P244',
#          'hash': 'fb463bf4063e242372e0eebcddbef4ab4b958f6e',
#          'datavalue': {'value': 'no95025028', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '0cd0399e778f66d514abac5cd6109335d422e78a',
#          'datavalue': {'value': {'time': '+2020-03-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P244', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P2163',
#      'hash': '8724d69fea5e195770441f819a9f2df27b8fd973',
#      'datavalue': {'value': '356304', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$9F22C401-E5C1-4069-BF40-C109EA8AE287',
#     'rank': 'normal',
#     'references': [{'hash': '803daa98c8dd64325aa0eba9edaef56cd3e92554',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'c120f07504c77593a9d734f50361ea829f601960',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 620946,
#            'id': 'Q620946'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P244': [{'snaktype': 'value',
#          'property': 'P244',
#          'hash': 'fb463bf4063e242372e0eebcddbef4ab4b958f6e',
#          'datavalue': {'value': 'no95025028', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '0cd0399e778f66d514abac5cd6109335d422e78a',
#          'datavalue': {'value': {'time': '+2020-03-25T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P244', 'P813']}]}],
#   'P6058': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P6058',
#      'hash': '5042ed4e38bdedbcfc66c8f5cb65a7336f9300a8',
#      'datavalue': {'value': 'personnage/wd/129819', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$ea4b404a-4b87-bcce-3a5f-b7bfd312f7ac',
#     'rank': 'normal'}],
#   'P8065': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8065',
#      'hash': 'd0af62c03d07d09728890d12a60b3241eabfe1b2',
#      'datavalue': {'value': '1244', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$D8AB3F4B-08AA-4961-A438-6D4D1B97E84E',
#     'rank': 'normal'}],
#   'P1711': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1711',
#      'hash': '2f966be72a0d27adb61bc1ed30eb1a268929eb85',
#      'datavalue': {'value': '140359', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$49ADFA4F-2DB6-46AA-8926-CD8A051D5D6A',
#     'rank': 'normal'}],
#   'P3222': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P3222',
#      'hash': '79f7c8f4f32bdfecd5b202fc52aefefbf78ee05a',
#      'datavalue': {'value': 'liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$93E44175-36AF-4DBA-B5DF-98931A69EC08',
#     'rank': 'normal'}],
#   'P4342': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P4342',
#      'hash': 'c1f9709b3ee2da126b68e4bdbad499e2959de423',
#      'datavalue': {'value': 'Liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$B96CC78C-A09C-4854-A77A-AD7A016BDAEB',
#     'rank': 'normal'}],
#   'P691': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P691',
#      'hash': 'fc906ec73ec147c35f633110b560a728f1e971e4',
#      'datavalue': {'value': 'skuk0003739', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$2FECBDEB-8DFA-4855-9093-6FEA902D0980',
#     'rank': 'normal'}],
#   'P6934': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P6934',
#      'hash': '12752d2c0235bee6f9f968c23414b71d5c323593',
#      'datavalue': {'value': '2494', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$2D77ADE0-452D-4BAD-AAFC-15F7F6FB26E4',
#     'rank': 'normal'}],
#   'P5019': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P5019',
#      'hash': 'f95f2f58dbcaa0085cb04edc9660b94684086510',
#      'datavalue': {'value': 'liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$4E7BF3C0-E5C2-4985-BBCA-261455174FCE',
#     'rank': 'normal'}],
#   'P8122': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8122',
#      'hash': 'd4653cf04552b315134ec3c7440675256a5557f8',
#      'datavalue': {'value': 'A5054', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$138C26BF-6C5F-4CD2-B346-93EBD6B84501',
#     'rank': 'normal'}],
#   'P7902': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7902',
#      'hash': '7c0cf6824672195aa0c6fe13157c0727e8c398b5',
#      'datavalue': {'value': '118779869', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$D9900A67-89F7-4B4A-9065-B7A26205F06E',
#     'rank': 'normal'}],
#   'P1047': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1047',
#      'hash': 'c91fc73fa9d369c616706141ec791f1985170b2f',
#      'datavalue': {'value': 'liberius', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$a23db71a-45e6-0566-53f5-13d1491d5e7d',
#     'rank': 'normal'}],
#   'P8189': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8189',
#      'hash': '3334f34c2506cf4ea5661dadbe3bb1bbc27fb9a1',
#      'datavalue': {'value': '987007397567805171', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q102105$5b6e7ebd-4e60-c501-3add-e2362c09b975',
#     'rank': 'normal',
#     'references': [{'hash': 'f2027a162f96dabf41f1fbcd3ecc2335889bcc9d',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': '3a89acbdf634a62b29f9857a1a09887af0beea82',
#          'datavalue': {'value': '58662922', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'b000b2311099faac2af992afcf13e6a11affb03e',
#          'datavalue': {'value': {'time': '+2020-07-05T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P409': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P409',
#      'hash': 'fd7415cef8dfdc16bdcad7eca95da898823da8e1',
#      'datavalue': {'value': '59618756', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q102105$39a7aca5-46df-1262-ccbc-4fb2f0089bbb',
#     'rank': 'normal',
#     'references': [{'hash': 'f2027a162f96dabf41f1fbcd3ecc2335889bcc9d',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': '3a89acbdf634a62b29f9857a1a09887af0beea82',
#          'datavalue': {'value': '58662922', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'b000b2311099faac2af992afcf13e6a11affb03e',
#          'datavalue': {'value': {'time': '+2020-07-05T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P214', 'P813']}]}],
#   'P8080': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8080',
#      'hash': '4c5a7aa58fe8f34ae078263966d3917627bcb0a6',
#      'datavalue': {'value': 'L/Liberius.html', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$23E8FCD8-F4DF-486F-9940-FD793B9A3959',
#     'rank': 'normal'}],
#   'P7038': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P7038',
#      'hash': 'ed28ec60cbe79a52389a0b05c240157c025b9f8d',
#      'datavalue': {'value': '01_01_0352-0366-_Liberius,_Sanctus',
#       'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$7B42668F-7BE0-4E17-AF37-914948D2C2C8',
#     'rank': 'normal'}],
#   'P8440': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8440',
#      'hash': '4a0f7e31726364803dd5e7588bb3f5cdca95d740',
#      'datavalue': {'value': '014-01555-001', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$D1469844-1ADF-4FA0-A4D3-2EE4BD0819C3',
#     'rank': 'normal'}],
#   'P1006': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1006',
#      'hash': '557e9b517e8508b1e56539a9e053bce740f67ccd',
#      'datavalue': {'value': '159583349', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'q102105$97542e00-486c-344e-bbe4-cc98843da587',
#     'rank': 'normal',
#     'references': [{'hash': '9f1a580f747c5666a6a64a2361c419aa7211f05f',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 54919,
#            'id': 'Q54919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P214': [{'snaktype': 'value',
#          'property': 'P214',
#          'hash': '38803e5e618ef24dc5eae227eb13e7101a65fa22',
#          'datavalue': {'value': '282188118', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '3419ec14b90509a2a733d9c1b0e1886bb6a4b0b4',
#          'datavalue': {'value': {'time': '+2020-07-31T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
# ...
#          'datavalue': {'value': 'no95025028', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'a487fa454f9fc1dc96e2ba8d683c91efdd05dc13',
#          'datavalue': {'value': {'time': '+2024-03-16T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P11797', 'P244', 'P813']}]}],
#   'P13049': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P13049',
#      'hash': '2e3e08295f86d925d69cba949e242d7ba83b53b8',
#      'datavalue': {'value': '118779869', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$B43053D4-6FC9-4903-9C6D-FB2A2B5FD96C',
#     'rank': 'normal'}],
#   'P6126': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P6126',
#      'hash': 'e017aefa8a0ec842de0a350d3d0f5b50c28a1b66',
#      'datavalue': {'value': '89036', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$C58E8487-71F2-48DE-97AD-6EA2B07CF232',
#     'rank': 'normal',
#     'references': [{'hash': 'b25b9ea60d99d0ec55d0ef66272c182612226860',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '5a343e7e758a4282a01316d3e959b6e653b767fc',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 11920,
#            'id': 'Q11920'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P4656': [{'snaktype': 'value',
#          'property': 'P4656',
#          'hash': '998d289f2da748215fa63ade0c281e6fb073a922',
#          'datavalue': {'value': 'https://it.wikipedia.org/w/index.php?title=Papa_Liberio&oldid=141734027',
#           'type': 'string'},
#          'datatype': 'url'}]},
#       'snaks-order': ['P143', 'P4656']}]}],
#   'P8168': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P8168',
#      'hash': '2b9a610f4d2c27eb6ffc434e1d8b70a4275678c6',
#      'datavalue': {'value': 'Q1298923', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q102105$E2999E40-C52E-4237-9E80-FE2F6DC98FE3',
#     'rank': 'normal',
#     'references': [{'hash': '717e1452e55538d1dd6a2fce6433a81fb7a420c9',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'e4afc4ad60f2160201385d29d076e0794f815f1e',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 90405608,
#            'id': 'Q90405608'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '04811fc19e5e67aedb6d73cda13320e313c06105',
#          'datavalue': {'value': {'time': '+2025-04-22T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P813']}]}]},
#  'sitelinks': {'afwiki': {'site': 'afwiki',
#    'title': 'Pous Liberius',
#    'badges': [],
#    'url': 'https://af.wikipedia.org/wiki/Pous_Liberius'},
#   'alswiki': {'site': 'alswiki',
#    'title': 'Liberius (Bischof von Rom)',
#    'badges': [],
#    'url': 'https://als.wikipedia.org/wiki/Liberius_(Bischof_von_Rom)'},
#   'arwiki': {'site': 'arwiki',
#    'title': 'ليبيريوس',
#    'badges': [],
#    'url': 'https://ar.wikipedia.org/wiki/%D9%84%D9%8A%D8%A8%D9%8A%D8%B1%D9%8A%D9%88%D8%B3'},
#   'arzwiki': {'site': 'arzwiki',
#    'title': 'القديس ليبيريوس',
#    'badges': [],
#    'url': 'https://arz.wikipedia.org/wiki/%D8%A7%D9%84%D9%82%D8%AF%D9%8A%D8%B3_%D9%84%D9%8A%D8%A8%D9%8A%D8%B1%D9%8A%D9%88%D8%B3'},
#   'astwiki': {'site': 'astwiki',
#    'title': 'Papa Liberiu',
#    'badges': [],
#    'url': 'https://ast.wikipedia.org/wiki/Papa_Liberiu'},
#   'be_x_oldwiki': {'site': 'be_x_oldwiki',
#    'title': 'Лібэрыюс (папа рымскі)',
#    'badges': [],
#    'url': 'https://be-tarask.wikipedia.org/wiki/%D0%9B%D1%96%D0%B1%D1%8D%D1%80%D1%8B%D1%8E%D1%81_(%D0%BF%D0%B0%D0%BF%D0%B0_%D1%80%D1%8B%D0%BC%D1%81%D0%BA%D1%96)'},
#   'bewiki': {'site': 'bewiki',
#    'title': 'Ліберый (Папа Рымскі)',
#    'badges': [],
#    'url': 'https://be.wikipedia.org/wiki/%D0%9B%D1%96%D0%B1%D0%B5%D1%80%D1%8B%D0%B9_(%D0%9F%D0%B0%D0%BF%D0%B0_%D0%A0%D1%8B%D0%BC%D1%81%D0%BA%D1%96)'},
#   'bgwiki': {'site': 'bgwiki',
#    'title': 'Либерий',
#    'badges': [],
#    'url': 'https://bg.wikipedia.org/wiki/%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%B9'},
#   'brwiki': {'site': 'brwiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://br.wikipedia.org/wiki/Liberius'},
#   'cawiki': {'site': 'cawiki',
#    'title': 'Papa Liberi',
#    'badges': [],
#    'url': 'https://ca.wikipedia.org/wiki/Papa_Liberi'},
#   'cdowiki': {'site': 'cdowiki',
#    'title': 'Gáu-huòng Liberius',
#    'badges': [],
#    'url': 'https://cdo.wikipedia.org/wiki/G%C3%A1u-hu%C3%B2ng_Liberius'},
#   'cebwiki': {'site': 'cebwiki',
#    'title': 'Liberio',
#    'badges': [],
#    'url': 'https://ceb.wikipedia.org/wiki/Liberio'},
#   'commonswiki': {'site': 'commonswiki',
#    'title': 'Category:Liberius',
#    'badges': [],
#    'url': 'https://commons.wikimedia.org/wiki/Category:Liberius'},
#   'cswiki': {'site': 'cswiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://cs.wikipedia.org/wiki/Liberius'},
#   'dawiki': {'site': 'dawiki',
#    'title': 'Pave Liberius',
#    'badges': [],
#    'url': 'https://da.wikipedia.org/wiki/Pave_Liberius'},
#   'dewiki': {'site': 'dewiki',
#    'title': 'Liberius (Bischof von Rom)',
#    'badges': [],
#    'url': 'https://de.wikipedia.org/wiki/Liberius_(Bischof_von_Rom)'},
#   'diqwiki': {'site': 'diqwiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://diq.wikipedia.org/wiki/Liberius'},
#   'elwiki': {'site': 'elwiki',
#    'title': 'Πάπας Λιβέριος',
#    'badges': [],
#    'url': 'https://el.wikipedia.org/wiki/%CE%A0%CE%AC%CF%80%CE%B1%CF%82_%CE%9B%CE%B9%CE%B2%CE%AD%CF%81%CE%B9%CE%BF%CF%82'},
#   'enwiki': {'site': 'enwiki',
#    'title': 'Pope Liberius',
#    'badges': [],
#    'url': 'https://en.wikipedia.org/wiki/Pope_Liberius'},
#   'enwikisource': {'site': 'enwikisource',
#    'title': 'Author:Liberius',
#    'badges': [],
#    'url': 'https://en.wikisource.org/wiki/Author:Liberius'},
#   'eowiki': {'site': 'eowiki',
#    'title': 'Libero (papo)',
#    'badges': [],
#    'url': 'https://eo.wikipedia.org/wiki/Libero_(papo)'},
#   'eswiki': {'site': 'eswiki',
#    'title': 'Liberio',
#    'badges': [],
#    'url': 'https://es.wikipedia.org/wiki/Liberio'},
#   'etwiki': {'site': 'etwiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://et.wikipedia.org/wiki/Liberius'},
#   'euwiki': {'site': 'euwiki',
#    'title': 'Liberio',
#    'badges': [],
#    'url': 'https://eu.wikipedia.org/wiki/Liberio'},
#   'fawiki': {'site': 'fawiki',
#    'title': 'لیبریوس',
#    'badges': [],
#    'url': 'https://fa.wikipedia.org/wiki/%D9%84%DB%8C%D8%A8%D8%B1%DB%8C%D9%88%D8%B3'},
#   'fiwiki': {'site': 'fiwiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://fi.wikipedia.org/wiki/Liberius'},
#   'frwiki': {'site': 'frwiki',
#    'title': 'Libère',
#    'badges': [],
#    'url': 'https://fr.wikipedia.org/wiki/Lib%C3%A8re'},
#   'gawiki': {'site': 'gawiki',
#    'title': 'Pápa Liberius',
#    'badges': [],
#    'url': 'https://ga.wikipedia.org/wiki/P%C3%A1pa_Liberius'},
#   'glwiki': {'site': 'glwiki',
#    'title': 'Liberio, papa',
#    'badges': [],
#    'url': 'https://gl.wikipedia.org/wiki/Liberio,_papa'},
#   'hakwiki': {'site': 'hakwiki',
#    'title': 'Kau-fòng Liberius',
#    'badges': [],
#    'url': 'https://hak.wikipedia.org/wiki/Kau-f%C3%B2ng_Liberius'},
#   'hewiki': {'site': 'hewiki',
#    'title': 'ליבריוס',
#    'badges': [],
#    'url': 'https://he.wikipedia.org/wiki/%D7%9C%D7%99%D7%91%D7%A8%D7%99%D7%95%D7%A1'},
#   'hrwiki': {'site': 'hrwiki',
#    'title': 'Liberije',
#    'badges': [],
#    'url': 'https://hr.wikipedia.org/wiki/Liberije'},
#   'huwiki': {'site': 'huwiki',
#    'title': 'Libériusz pápa',
#    'badges': [],
#    'url': 'https://hu.wikipedia.org/wiki/Lib%C3%A9riusz_p%C3%A1pa'},
#   'hywiki': {'site': 'hywiki',
#    'title': 'Լիբերիոս (Հռոմի պապ)',
#    'badges': [],
#    'url': 'https://hy.wikipedia.org/wiki/%D4%BC%D5%AB%D5%A2%D5%A5%D6%80%D5%AB%D5%B8%D5%BD_(%D5%80%D5%BC%D5%B8%D5%B4%D5%AB_%D5%BA%D5%A1%D5%BA)'},
#   'idwiki': {'site': 'idwiki',
#    'title': 'Paus Liberius',
#    'badges': [],
#    'url': 'https://id.wikipedia.org/wiki/Paus_Liberius'},
#   'ilowiki': {'site': 'ilowiki',
#    'title': 'Papa Liberio',
#    'badges': [],
#    'url': 'https://ilo.wikipedia.org/wiki/Papa_Liberio'},
#   'iowiki': {'site': 'iowiki',
#    'title': 'Papo Liberius',
#    'badges': [],
#    'url': 'https://io.wikipedia.org/wiki/Papo_Liberius'},
#   'itwiki': {'site': 'itwiki',
#    'title': 'Papa Liberio',
#    'badges': [],
#    'url': 'https://it.wikipedia.org/wiki/Papa_Liberio'},
#   'itwikiquote': {'site': 'itwikiquote',
#    'title': 'Papa Liberio',
#    'badges': [],
#    'url': 'https://it.wikiquote.org/wiki/Papa_Liberio'},
#   'jawiki': {'site': 'jawiki',
#    'title': 'リベリウス (ローマ教皇)',
#    'badges': [],
#    'url': 'https://ja.wikipedia.org/wiki/%E3%83%AA%E3%83%99%E3%83%AA%E3%82%A6%E3%82%B9_(%E3%83%AD%E3%83%BC%E3%83%9E%E6%95%99%E7%9A%87)'},
#   'jvwiki': {'site': 'jvwiki',
#    'title': 'Paus Liberius',
#    'badges': [],
#    'url': 'https://jv.wikipedia.org/wiki/Paus_Liberius'},
#   'kawiki': {'site': 'kawiki',
#    'title': 'ლიბერიუსი (პაპი)',
#    'badges': [],
#    'url': 'https://ka.wikipedia.org/wiki/%E1%83%9A%E1%83%98%E1%83%91%E1%83%94%E1%83%A0%E1%83%98%E1%83%A3%E1%83%A1%E1%83%98_(%E1%83%9E%E1%83%90%E1%83%9E%E1%83%98)'},
#   'kowiki': {'site': 'kowiki',
#    'title': '교황 리베리오',
#    'badges': [],
#    'url': 'https://ko.wikipedia.org/wiki/%EA%B5%90%ED%99%A9_%EB%A6%AC%EB%B2%A0%EB%A6%AC%EC%98%A4'},
#   'lawiki': {'site': 'lawiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://la.wikipedia.org/wiki/Liberius'},
#   'lawikisource': {'site': 'lawikisource',
#    'title': 'Scriptor:Liberius',
#    'badges': [],
#    'url': 'https://la.wikisource.org/wiki/Scriptor:Liberius'},
#   'lvwiki': {'site': 'lvwiki',
#    'title': 'Libērijs',
#    'badges': [],
#    'url': 'https://lv.wikipedia.org/wiki/Lib%C4%93rijs'},
#   'mgwiki': {'site': 'mgwiki',
#    'title': 'Liberio (papa)',
#    'badges': [],
#    'url': 'https://mg.wikipedia.org/wiki/Liberio_(papa)'},
#   'mkwiki': {'site': 'mkwiki',
#    'title': 'Папа Либериј',
#    'badges': [],
#    'url': 'https://mk.wikipedia.org/wiki/%D0%9F%D0%B0%D0%BF%D0%B0_%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D1%98'},
#   'mrwiki': {'site': 'mrwiki',
#    'title': 'पोप लायबेरियस',
#    'badges': [],
#    'url': 'https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8B%E0%A4%AA_%E0%A4%B2%E0%A4%BE%E0%A4%AF%E0%A4%AC%E0%A5%87%E0%A4%B0%E0%A4%BF%E0%A4%AF%E0%A4%B8'},
#   'mswiki': {'site': 'mswiki',
#    'title': 'Paus Liberius',
#    'badges': [],
#    'url': 'https://ms.wikipedia.org/wiki/Paus_Liberius'},
#   'mznwiki': {'site': 'mznwiki',
#    'title': 'لیبریوس',
#    'badges': [],
#    'url': 'https://mzn.wikipedia.org/wiki/%D9%84%DB%8C%D8%A8%D8%B1%DB%8C%D9%88%D8%B3'},
#   'ndswiki': {'site': 'ndswiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://nds.wikipedia.org/wiki/Liberius'},
#   'nlwiki': {'site': 'nlwiki',
#    'title': 'Paus Liberius',
#    'badges': [],
#    'url': 'https://nl.wikipedia.org/wiki/Paus_Liberius'},
#   'nowiki': {'site': 'nowiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://no.wikipedia.org/wiki/Liberius'},
#   'ocwiki': {'site': 'ocwiki',
#    'title': 'Libèri',
#    'badges': [],
#    'url': 'https://oc.wikipedia.org/wiki/Lib%C3%A8ri'},
#   'plwiki': {'site': 'plwiki',
#    'title': 'Liberiusz (papież)',
#    'badges': [],
#    'url': 'https://pl.wikipedia.org/wiki/Liberiusz_(papie%C5%BC)'},
#   'ptwiki': {'site': 'ptwiki',
#    'title': 'Papa Libério',
#    'badges': [],
#    'url': 'https://pt.wikipedia.org/wiki/Papa_Lib%C3%A9rio'},
#   'rowiki': {'site': 'rowiki',
#    'title': 'Papa Liberiu',
#    'badges': [],
#    'url': 'https://ro.wikipedia.org/wiki/Papa_Liberiu'},
#   'ruwiki': {'site': 'ruwiki',
#    'title': 'Либерий (папа римский)',
#    'badges': [],
#    'url': 'https://ru.wikipedia.org/wiki/%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%B9_(%D0%BF%D0%B0%D0%BF%D0%B0_%D1%80%D0%B8%D0%BC%D1%81%D0%BA%D0%B8%D0%B9)'},
#   'ruwikinews': {'site': 'ruwikinews',
#    'title': 'Категория:Либерий (папа римский)',
#    'badges': [],
#    'url': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%B9_(%D0%BF%D0%B0%D0%BF%D0%B0_%D1%80%D0%B8%D0%BC%D1%81%D0%BA%D0%B8%D0%B9)'},
#   'shwiki': {'site': 'shwiki',
#    'title': 'Liberije (papa)',
#    'badges': [],
#    'url': 'https://sh.wikipedia.org/wiki/Liberije_(papa)'},
#   'simplewiki': {'site': 'simplewiki',
#    'title': 'Pope Liberius',
#    'badges': [],
#    'url': 'https://simple.wikipedia.org/wiki/Pope_Liberius'},
#   'skwiki': {'site': 'skwiki',
#    'title': 'Libérius',
#    'badges': [],
#    'url': 'https://sk.wikipedia.org/wiki/Lib%C3%A9rius'},
#   'slwiki': {'site': 'slwiki',
#    'title': 'Papež Liberij',
#    'badges': [],
#    'url': 'https://sl.wikipedia.org/wiki/Pape%C5%BE_Liberij'},
#   'sqwiki': {'site': 'sqwiki',
#    'title': 'Liberi',
#    'badges': [],
#    'url': 'https://sq.wikipedia.org/wiki/Liberi'},
#   'srwiki': {'site': 'srwiki',
#    'title': 'Папа Либерије',
#    'badges': [],
#    'url': 'https://sr.wikipedia.org/wiki/%D0%9F%D0%B0%D0%BF%D0%B0_%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D1%98%D0%B5'},
#   'srwikiquote': {'site': 'srwikiquote',
#    'title': 'Папа Либерије',
#    'badges': [],
#    'url': 'https://sr.wikiquote.org/wiki/%D0%9F%D0%B0%D0%BF%D0%B0_%D0%9B%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D1%98%D0%B5'},
#   'svwiki': {'site': 'svwiki',
#    'title': 'Liberius',
#    'badges': [],
#    'url': 'https://sv.wikipedia.org/wiki/Liberius'},
#   'swwiki': {'site': 'swwiki',
#    'title': 'Papa Liberius',
#    'badges': [],
#    'url': 'https://sw.wikipedia.org/wiki/Papa_Liberius'},
#   'tawiki': {'site': 'tawiki',
#    'title': 'லிபேரியஸ் (திருத்தந்தை)',
#    'badges': [],
#    'url': 'https://ta.wikipedia.org/wiki/%E0%AE%B2%E0%AE%BF%E0%AE%AA%E0%AF%87%E0%AE%B0%E0%AE%BF%E0%AE%AF%E0%AE%B8%E0%AF%8D_(%E0%AE%A4%E0%AE%BF%E0%AE%B0%E0%AF%81%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AE%A8%E0%AF%8D%E0%AE%A4%E0%AF%88)'},
#   'tlwiki': {'site': 'tlwiki',
#    'title': 'Papa Liberio',
#    'badges': [],
#    'url': 'https://tl.wikipedia.org/wiki/Papa_Liberio'},
#   'trwiki': {'site': 'trwiki',
#    'title': 'Liberius (papa)',
#    'badges': [],
#    'url': 'https://tr.wikipedia.org/wiki/Liberius_(papa)'},
#   'ukwiki': {'site': 'ukwiki',
#    'title': 'Ліберій',
#    'badges': [],
#    'url': 'https://uk.wikipedia.org/wiki/%D0%9B%D1%96%D0%B1%D0%B5%D1%80%D1%96%D0%B9'},
#   'urwiki': {'site': 'urwiki',
#    'title': 'لیبیریوس',
#    'badges': [],
#    'url': 'https://ur.wikipedia.org/wiki/%D9%84%DB%8C%D8%A8%DB%8C%D8%B1%DB%8C%D9%88%D8%B3'},
#   'viwiki': {'site': 'viwiki',
#    'title': 'Giáo hoàng Libêriô',
#    'badges': [],
#    'url': 'https://vi.wikipedia.org/wiki/Gi%C3%A1o_ho%C3%A0ng_Lib%C3%AAri%C3%B4'},
#   'warwiki': {'site': 'warwiki',
#    'title': 'Papa Liberio',
#    'badges': [],
#    'url': 'https://war.wikipedia.org/wiki/Papa_Liberio'},
#   'wuuwiki': {'site': 'wuuwiki',
#    'title': '教宗利伯略',
#    'badges': [],
#    'url': 'https://wuu.wikipedia.org/wiki/%E6%95%99%E5%AE%97%E5%88%A9%E4%BC%AF%E7%95%A5'},
#   'yowiki': {'site': 'yowiki',
#    'title': 'Pópù Liberius',
#    'badges': [],
#    'url': 'https://yo.wikipedia.org/wiki/P%C3%B3p%C3%B9_Liberius'},
#   'zh_min_nanwiki': {'site': 'zh_min_nanwiki',
#    'title': 'Kàu-hông Liberius',
#    'badges': [],
#    'url': 'https://zh-min-nan.wikipedia.org/wiki/K%C3%A0u-h%C3%B4ng_Liberius'},
#   'zh_yuewiki': {'site': 'zh_yuewiki',
#    'title': '立柏',
#    'badges': [],
#    'url': 'https://zh-yue.wikipedia.org/wiki/%E7%AB%8B%E6%9F%8F'},
#   'zhwiki': {'site': 'zhwiki',
#    'title': '教宗利伯略',
#    'badges': [],
#    'url': 'https://zh.wikipedia.org/wiki/%E6%95%99%E5%AE%97%E5%88%A9%E4%BC%AF%E7%95%A5'}}}

# %% [markdown]
# ## Čištění

# %%
papez['entities'][list(papez['entities'])[0]]['labels']['cs']['value']
# Out:
# 'František'

# %% [markdown]
# ### Narození

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P19'][0]['mainsnak']['datavalue']['value']['id']
# Out:
# 'Q643907'

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time']
# Out:
# '+1936-12-17T00:00:00Z'

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P569'][0]['mainsnak']['datavalue']['value']['precision']
# Out:
# 11

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P1636'][0]['mainsnak']['datavalue']['value']['time']
# Out:
# '+1936-12-25T00:00:00Z'

# %% [markdown]
# ### Úmrtí

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P20'][0]['mainsnak']['datavalue']['value']['id']
# Out:
# 'Q237'

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time']
# Out:
# '+2025-04-21T00:00:00Z'

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P570'][0]['mainsnak']['datavalue']['value']['precision']
# Out:
# 11

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
# Out:
# 'Q3739104'

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
# Out:
# 'Q12202'

# %% [markdown]
# ### Další

# %%
papez['entities'][list(papez['entities'])[0]]['claims']['P21'][0]['mainsnak']['datavalue']['value']['id']
# Out:
# 'Q6581097'

# %%
for funkce in papez['entities'][list(papez['entities'])[0]]['claims']['P39']:
    if funkce['mainsnak']['datavalue']['value']['id'] == 'Q19546':
        print(funkce['qualifiers']['P580'][0]['datavalue']['value']['time'])
# Out:
# +2013-03-13T00:00:00Z

# %%
for funkce in papez['entities'][list(papez['entities'])[0]]['claims']['P39']:
    if funkce['mainsnak']['datavalue']['value']['id'] == 'Q19546':
        print(funkce['qualifiers']['P582'][0]['datavalue']['value']['time'])
# Out:
# +2025-04-21T00:00:00Z

# %%
for rodny_jazyk in (papez['entities'][list(papez['entities'])[0]]['claims']['P103']):
    print(rodny_jazyk['mainsnak']['datavalue']['value']['id'])
# Out:
# Q1321

# %%
for dalsi_jazyk in (papez['entities'][list(papez['entities'])[0]]['claims']['P1412']):
    print(dalsi_jazyk['mainsnak']['datavalue']['value']['id'])
# Out:
# Q1321
# Q652
# Q397
# Q188
# Q150
# Q5146
# Q1860
# Q1247932

# %%
for povolani in (papez['entities'][list(papez['entities'])[0]]['claims']['P106']):
    print(povolani['mainsnak']['datavalue']['value']['id'])
# Out:
# Q1469535
# Q593644
# Q36180
# Q1234713
# Q432386
# Q16827718
# Q352507
# Q102039658
# Q611644
# Q82955
# Q482980

# %%
for rad in (papez['entities'][list(papez['entities'])[0]]['claims']['P611']):
    print(rad['mainsnak']['datavalue']['value']['id'])
# Out:
# Q36380

# %%
for ucastnik in (papez['entities'][list(papez['entities'])[0]]['claims']['P1344']):
    print(ucastnik['mainsnak']['datavalue']['value']['id'])
# Out:
# Q4422669
# Q666536

# %%
len(papez['entities'][list(papez['entities'])[0]]['sitelinks'])
# Out:
# 222

# %%
[x for x in list(papez['entities'][list(papez['entities'])[0]]['sitelinks'].keys()) if x[-4:] == 'wiki']
# Out:
# ['acewiki',
#  'afwiki',
#  'alswiki',
#  'amwiki',
#  'anwiki',
#  'arwiki',
#  'arzwiki',
#  'astwiki',
#  'avwiki',
#  'aywiki',
#  'azbwiki',
#  'azwiki',
#  'barwiki',
#  'bat_smgwiki',
#  'bclwiki',
#  'be_x_oldwiki',
#  'bewiki',
#  'bewwiki',
#  'bgwiki',
#  'bjnwiki',
#  'bnwiki',
#  'brwiki',
#  'bswiki',
#  'cawiki',
#  'cbk_zamwiki',
#  'cdowiki',
#  'cebwiki',
#  'ckbwiki',
#  'commonswiki',
#  'cowiki',
#  'csbwiki',
#  'cswiki',
#  'cywiki',
#  'dawiki',
#  'dewiki',
#  'diqwiki',
#  'dsbwiki',
#  'dtpwiki',
#  'elwiki',
#  'emlwiki',
#  'enwiki',
#  'eowiki',
#  'eswiki',
#  'etwiki',
#  'euwiki',
#  'extwiki',
#  'fawiki',
#  'ffwiki',
#  'fiwiki',
#  'fonwiki',
#  'fowiki',
#  'frpwiki',
#  'frrwiki',
#  'frwiki',
#  'furwiki',
#  'fywiki',
#  'gawiki',
#  'gdwiki',
#  'glwiki',
#  'gnwiki',
#  'gomwiki',
#  'gotwiki',
#  'hakwiki',
#  'hawiki',
#  'hewiki',
#  'hiwiki',
#  'hrwiki',
#  'hsbwiki',
#  'huwiki',
#  'hywiki',
#  'iawiki',
#  'ibawiki',
#  'idwiki',
#  'iewiki',
#  'ilowiki',
#  'iowiki',
#  'iswiki',
#  'itwiki',
#  'jawiki',
#  'jvwiki',
#  'kawiki',
#  'kbpwiki',
#  'kkwiki',
#  'kmwiki',
#  'kncwiki',
#  'kowiki',
#  'kuwiki',
#  'kwwiki',
#  'ladwiki',
#  'lawiki',
#  'lbwiki',
#  'lfnwiki',
#  'lijwiki',
#  'liwiki',
#  'lmowiki',
#  'lnwiki',
#  'lowiki',
#  'ltwiki',
#  'lvwiki',
#  'maiwiki',
#  'mgwiki',
#  'mkwiki',
#  'mlwiki',
#  'mnwiki',
#  'mrwiki',
#  'mswiki',
#  'mtwiki',
#  'mwlwiki',
#  'mywiki',
#  'mznwiki',
#  'nahwiki',
#  'napwiki',
#  'ndswiki',
#  'newiki',
#  'niawiki',
#  'nlwiki',
#  'nnwiki',
#  'novwiki',
#  'nowiki',
#  'ocwiki',
#  'pamwiki',
#  'papwiki',
#  'pawiki',
#  'pcdwiki',
#  'pdcwiki',
#  'plwiki',
#  'pmswiki',
#  'pnbwiki',
#  'ptwiki',
#  'quwiki',
#  'roa_tarawiki',
#  'rowiki',
#  'ruwiki',
#  'scnwiki',
#  'scowiki',
#  'scwiki',
#  'shwiki',
#  'simplewiki',
#  'siwiki',
#  'skwiki',
#  'slwiki',
#  'smnwiki',
#  'sqwiki',
#  'srwiki',
#  'sswiki',
#  'suwiki',
#  'svwiki',
#  'swwiki',
#  'szlwiki',
#  'tawiki',
#  'tewiki',
#  'thwiki',
#  'tlwiki',
#  'tpiwiki',
#  'trwiki',
#  'ttwiki',
#  'ukwiki',
#  'urwiki',
#  'uzwiki',
#  'vecwiki',
#  'viwiki',
#  'vowiki',
#  'warwiki',
#  'wawiki',
#  'wuuwiki',
#  'xmfwiki',
#  'yowiki',
#  'zeawiki',
#  'zh_min_nanwiki',
#  'zh_yuewiki',
#  'zhwiki']

# %%
papez['entities'][list(papez['entities'])[0]]['claims'].keys()
# Out:
# dict_keys(['P1598', 'P1280', 'P39', 'P19', 'P27', 'P94', 'P103', 'P214', 'P244', 'P227', 'P269', 'P237', 'P373', 'P569', 'P396', 'P409', 'P109', 'P213', 'P511', 'P646', 'P31', 'P910', 'P1047', 'P906', 'P735', 'P1273', 'P1017', 'P950', 'P1005', 'P349', 'P1207', 'P1006', 'P140', 'P1477', 'P1284', 'P611', 'P2002', 'P69', 'P1412', 'P22', 'P25', 'P935', 'P2163', 'P949', 'P166', 'P434', 'P2003', 'P2949', 'P3221', 'P3222', 'P989', 'P1617', 'P3417', 'P3788', 'P345', 'P2611', 'P3106', 'P1451', 'P793', 'P1015', 'P1953', 'P512', 'P1368', 'P4862', 'P1424', 'P3219', 'P1636', 'P5019', 'P1635', 'P1066', 'P2924', 'P5587', 'P1417', 'P2963', 'P734', 'P268', 'P691', 'P21', 'P5361', 'P1375', 'P3280', 'P5034', 'P3065', 'P6394', 'P4619', 'P271', 'P1670', 'P1315', 'P5739', 'P1344', 'P1741', 'P5905', 'P4839', 'P6886', 'P7157', 'P1343', 'P3365', 'P4521', 'P2605', 'P7796', 'P5731', 'P7865', 'P6058', 'P7902', 'P3348', 'P6758', 'P8034', 'P2600', 'P8286', 'P1819', 'P5337', 'P6706', 'P6200', 'P7982', 'P8748', 'P8795', 'P4527', 'P7293', 'P8980', 'P9037', 'P4789', 'P8885', 'P7775', 'P3987', 'P9368', 'P7369', 'P8179', 'P3846', 'P8189', 'P7699', 'P7029', 'P7700', 'P7024', 'P7619', 'P4985', 'P9534', 'P5421', 'P9522', 'P7212', 'P9629', 'P9984', 'P18', 'P10031', 'P648', 'P10266', 'P2604', 'P9995', 'P7305', 'P3368', 'P8313', 'P9943', 'P2190', 'P10553', 'P10227', 'P10660', 'P4666', 'P4342', 'P800', 'P11120', 'P5008', 'P101', 'P11194', 'P8879', 'P10302', 'P1185', 'P10632', 'P11249', 'P11496', 'P5695', 'P10699', 'P8568', 'P11686', 'P9171', 'P11835', 'P11828', 'P10166', 'P2581', 'P7502', 'P10780', 'P11514', 'P8445', 'P106', 'P12098', 'P12086', 'P12299', 'P12288', 'P11245', 'P12458', 'P10328', 'P12153', 'P12597', 'P10832', 'P12800', 'P13030', 'P13019', 'P5404', 'P8819', 'P1728', 'P6760', 'P13049', 'P7050', 'P1309', 'P1607', 'P13166', 'P5551', 'P9346', 'P13183', 'P5558', 'P13201', 'P8669', 'P11936', 'P10291', 'P138', 'P1266', 'P1712', 'P10387', 'P570', 'P20', 'P1196', 'P509', 'P11483', 'P2889', 'P856', 'P2397', 'P4440', 'P1048', 'P947', 'P4012', 'P8168'])

# %% [markdown]
# ## Syntéza

# %%
def proklepni_papeze(papez):
    
    data_o_papezi = {}
    
    try:
        data_o_papezi['jmeno'] = papez['entities'][list(papez['entities'])[0]]['labels']['cs']['value']
    except:
        data_o_papezi['jmeno'] = papez['entities'][list(papez['entities'])[0]]['labels']['en']['value']

    try:
        data_o_papezi['narozeni_misto'] = papez['entities'][list(papez['entities'])[0]]['claims']['P19'][0]['mainsnak']['datavalue']['value']['id']
    except:
        data_o_papezi['narozeni_misto'] = None

    try:
        data_o_papezi['narozeni_datum'] = papez['entities'][list(papez['entities'])[0]]['claims']['P569'][0]['mainsnak']['datavalue']['value']['time'][1:11]
    except:
        data_o_papezi['narozeni_datum'] = None

    try:
        data_o_papezi['narozeni_presnost'] = papez['entities'][list(papez['entities'])[0]]['claims']['P569'][0]['mainsnak']['datavalue']['value']['precision']
    except:
        data_o_papezi['narozeni_presnost'] = None

    try:
        data_o_papezi['krest_datum'] = papez['entities'][list(papez['entities'])[0]]['claims']['P1636'][0]['mainsnak']['datavalue']['value']['time'][1:11]
    except:
        data_o_papezi['krest_datum'] = None

    try:
        data_o_papezi['umrti_misto'] = papez['entities'][list(papez['entities'])[0]]['claims']['P20'][0]['mainsnak']['datavalue']['value']['id']
    except:
        data_o_papezi['umrti_misto'] = None

    try:
        data_o_papezi['umrti_datum'] = papez['entities'][list(papez['entities'])[0]]['claims']['P570'][0]['mainsnak']['datavalue']['value']['time'][1:11]
    except:
        data_o_papezi['umrti_datum'] = None

    try:
        data_o_papezi['umrti_presnost'] = papez['entities'][list(papez['entities'])[0]]['claims']['P570'][0]['mainsnak']['datavalue']['value']['precision']
    except:
        data_o_papezi['umrti_presnost'] = None

    try:
        data_o_papezi['umrti_kategorie'] = papez['entities'][list(papez['entities'])[0]]['claims']['P1196'][0]['mainsnak']['datavalue']['value']['id']
    except:
        data_o_papezi['umrti_kategorie'] = None

    try:
        data_o_papezi['umrti_pricina'] = papez['entities'][list(papez['entities'])[0]]['claims']['P509'][0]['mainsnak']['datavalue']['value']['id']
    except:
        data_o_papezi['umrti_pricina'] = None

    try:
        for funkce in papez['entities'][list(papez['entities'])[0]]['claims']['P39']:
            if funkce['mainsnak']['datavalue']['value']['id'] == 'Q19546':
                data_o_papezi['pontifikat_zacatek'] = funkce['qualifiers']['P580'][0]['datavalue']['value']['time'][1:11]
    except:
        data_o_papezi['pontifikat_zacatek'] = None
    
    try:
        for funkce in papez['entities'][list(papez['entities'])[0]]['claims']['P39']:
            if funkce['mainsnak']['datavalue']['value']['id'] == 'Q19546':
                data_o_papezi['pontifikat_konec']  = funkce['qualifiers']['P582'][0]['datavalue']['value']['time'][1:11]
    except:
        data_o_papezi['pontifikat_konec'] = None
    
    try:
        rodne_jazyky = []
        for rodny_jazyk in papez['entities'][list(papez['entities'])[0]]['claims']['P103']:
            rodne_jazyky.append(rodny_jazyk['mainsnak']['datavalue']['value']['id'])
        data_o_papezi['rodny_jazyk'] = rodne_jazyky
    except:
        data_o_papezi['rodny_jazyk'] = None

    try:
        dalsi_jazyky = []
        for dalsi_jazyk in papez['entities'][list(papez['entities'])[0]]['claims']['P1412']:
            dalsi_jazyky.append(dalsi_jazyk['mainsnak']['datavalue']['value']['id'])
        data_o_papezi['dalsi_jazyky'] = dalsi_jazyky
    except:
        data_o_papezi['dalsi_jazyky'] = None

    try:
        povolani = []
        for profese in papez['entities'][list(papez['entities'])[0]]['claims']['P106']:
            povolani.append(profese['mainsnak']['datavalue']['value']['id'])
        data_o_papezi['povolani'] = povolani
    except:
        data_o_papezi['povolani'] = None

    try:
        rady = []
        for rad in papez['entities'][list(papez['entities'])[0]]['claims']['P611']:
            rady.apppend(rad['mainsnak']['datavalue']['value']['id'])
        data_o_papezi['rady'] = rady
    except:
        data_o_papezi['rady'] = None

    try:
        ucastnil_se = []
        for ucastnik in papez['entities'][list(papez['entities'])[0]]['claims']['P1344']:
            ucastnil_se.append(ucastnik['mainsnak']['datavalue']['value']['id'])
        data_o_papezi['ucastnik'] = ucastnil_se
    except:
        data_o_papezi['ucastnik'] = None

    data_o_papezi['wikihesla'] = [x for x in list(papez['entities'][list(papez['entities'])[0]]['sitelinks'].keys()) if x[-4:] == 'wiki']
    
    return data_o_papezi

papezstvo = []

for p in os.listdir(cesta):
    if 'Q' in p:
        with open(os.path.join(cesta, p), 'r', encoding='utf-8') as soubor_s_papezem:
            obsah_souboru_s_papezem = json.loads(soubor_s_papezem.read())
            papezstvo.append(proklepni_papeze(obsah_souboru_s_papezem))

# %%
import sys

# %%
sys.getsizeof(papezstvo)
# Out:
# 2200

# %%
papezstvo[250]
# Out:
# {'jmeno': 'Lev IX.',
#  'narozeni_misto': 'Q272897',
#  'narozeni_datum': '1002-06-21',
#  'narozeni_presnost': 11,
#  'krest_datum': None,
#  'umrti_misto': 'Q220',
#  'umrti_datum': '1054-04-19',
#  'umrti_presnost': 11,
#  'umrti_kategorie': 'Q3739104',
#  'umrti_pricina': 'Q12156',
#  'pontifikat_zacatek': '1049-02-18',
#  'pontifikat_konec': '1054-04-19',
#  'rodny_jazyk': None,
#  'dalsi_jazyky': ['Q397'],
#  'povolani': ['Q250867', 'Q36180'],
#  'rady': None,
#  'ucastnik': None,
#  'wikihesla': ['afwiki',
#   'arwiki',
#   'arzwiki',
#   'bewiki',
#   'bgwiki',
#   'brwiki',
#   'cawiki',
#   'cdowiki',
#   'commonswiki',
#   'cswiki',
#   'dewiki',
#   'diqwiki',
#   'elwiki',
#   'enwiki',
#   'eowiki',
#   'eswiki',
#   'etwiki',
#   'euwiki',
#   'fawiki',
#   'fiwiki',
#   'frwiki',
#   'gawiki',
#   'glwiki',
#   'hakwiki',
#   'hewiki',
#   'hrwiki',
#   'huwiki',
#   'hywiki',
#   'idwiki',
#   'ilowiki',
#   'iowiki',
#   'itwiki',
#   'jawiki',
#   'jvwiki',
#   'kawiki',
#   'kowiki',
#   'lawiki',
#   'ltwiki',
#   'lvwiki',
#   'mgwiki',
#   'mkwiki',
#   'mrwiki',
#   'mswiki',
#   'mznwiki',
#   'nlwiki',
#   'nowiki',
#   'plwiki',
#   'ptwiki',
#   'quwiki',
#   'rowiki',
#   'ruwiki',
#   'scnwiki',
#   'shwiki',
#   'skwiki',
#   'slwiki',
#   'sqwiki',
#   'srwiki',
#   'svwiki',
#   'swwiki',
#   'tlwiki',
#   'trwiki',
#   'ukwiki',
#   'urwiki',
#   'viwiki',
#   'warwiki',
#   'wuuwiki',
#   'yowiki',
#   'zh_min_nanwiki',
#   'zh_yuewiki',
#   'zhwiki']}

# %%
df = pl.DataFrame(papezstvo, orient="row", infer_schema_length=None).sort(by='pontifikat_zacatek')

# %%
df.filter(pl.col('dalsi_jazyky').is_null())
# Out:
# shape: (90, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬──────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ dalsi_jaz ┆ povolani  ┆ rady ┆ ucastnik │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ yky       ┆ ---       ┆ ---  ┆ ---      │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ list[str] ┆ null ┆ list[str │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆ list[str] ┆           ┆      ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪══════╪══════════╡
# │ Cardinal  ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ ["Q42603" ┆ null ┆ null     │
# │ Lamberto  ┆           ┆           ┆           ┆   ┆           ┆ ]         ┆      ┆          │
# │ Jewish    ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ ["Q831474 ┆ null ┆ null     │
# │ pope      ┆           ┆           ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ Andreas   ┆           ┆           ┆           ┆   ┆           ┆           ┆      ┆          │
# │ svatý     ┆ Q501773   ┆ 0001-00-0 ┆ 9         ┆ … ┆ null      ┆ ["Q831474 ┆ null ┆ null     │
# │ Petr      ┆           ┆ 0         ┆           ┆   ┆           ┆ ", "Q3314 ┆      ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 32",      ┆      ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "Q61164…  ┆      ┆          │
# │ Alexandr  ┆ Q220      ┆ 0100-00-0 ┆ 7         ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ null     │
# │ I.        ┆           ┆ 0         ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ Sixtus I. ┆ Q220      ┆ 0042-00-0 ┆ 9         ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ null     │
# │           ┆           ┆ 0         ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …    ┆ …        │
# │ Lev XI.   ┆ Q2044     ┆ 1535-06-0 ┆ 11        ┆ … ┆ null      ┆ ["Q193391 ┆ null ┆ ["Q45422 │
# │           ┆           ┆ 2         ┆           ┆   ┆           ┆ ", "Q2508 ┆      ┆ 46", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 67",      ┆      ┆ 773050", │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "Q61164…  ┆      ┆ … "Q4…   │
# │ Řehoř XV. ┆ Q1891     ┆ 1554-01-0 ┆ 11        ┆ … ┆ null      ┆ ["Q146953 ┆ null ┆ ["Q47026 │
# │           ┆           ┆ 9         ┆           ┆   ┆           ┆ 5"]       ┆      ┆ 78"]     │
# │ Inocenc   ┆ Q220      ┆ 1574-05-0 ┆ 11        ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ ["Q14031 │
# │ X.        ┆           ┆ 6         ┆           ┆   ┆           ┆ ", "Q1933 ┆      ┆ 60"]     │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 91"]      ┆      ┆          │
# │ Inocenc   ┆ Q243168   ┆ 1655-05-1 ┆ 11        ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ ["Q23898 │
# │ XIII.     ┆           ┆ 3         ┆           ┆   ┆           ┆ "]        ┆      ┆ 17"]     │
# │ Pius      ┆ Q73649    ┆ 1761-11-2 ┆ 11        ┆ … ┆ null      ┆ ["Q146953 ┆ null ┆ ["Q20196 │
# │ VIII.     ┆           ┆ 0         ┆           ┆   ┆           ┆ 5", "Q611 ┆      ┆ 78", "Q2 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 644"]     ┆      ┆ 448354"] │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴──────┴──────────┘

# %%
df.filter(~pl.col('dalsi_jazyky').is_null())
# Out:
# shape: (177, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬──────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ dalsi_jaz ┆ povolani  ┆ rady ┆ ucastnik │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ yky       ┆ ---       ┆ ---  ┆ ---      │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ list[str] ┆ null ┆ list[str │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆ list[str] ┆           ┆      ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪══════╪══════════╡
# │ Linus     ┆ Q1273     ┆ 0010-01-0 ┆ 9         ┆ … ┆ ["Q397"]  ┆ ["Q105200 ┆ null ┆ null     │
# │           ┆           ┆ 1         ┆           ┆   ┆           ┆ 223"]     ┆      ┆          │
# │ Anaklét   ┆ Q220      ┆ 0025-00-0 ┆ 9         ┆ … ┆ ["Q36510" ┆ ["Q250867 ┆ null ┆ null     │
# │           ┆           ┆ 0         ┆           ┆   ┆ ]         ┆ "]        ┆      ┆          │
# │ Klement   ┆ Q220      ┆ 0100-00-0 ┆ 7         ┆ … ┆ ["Q397"]  ┆ ["Q123471 ┆ null ┆ null     │
# │ I.        ┆           ┆ 0         ┆           ┆   ┆           ┆ 3", "Q250 ┆      ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 867"]     ┆      ┆          │
# │ Evaristus ┆ Q200441   ┆ 0100-00-0 ┆ 7         ┆ … ┆ ["Q36510" ┆ ["Q250867 ┆ null ┆ null     │
# │           ┆           ┆ 0         ┆           ┆   ┆ ]         ┆ "]        ┆      ┆          │
# │ Telesforu ┆ Q54024    ┆ null      ┆ null      ┆ … ┆ ["Q107358 ┆ ["Q250867 ┆ null ┆ null     │
# │ s         ┆           ┆           ┆           ┆   ┆ "]        ┆ "]        ┆      ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …    ┆ …        │
# │ Pavel VI. ┆ Q104074   ┆ 1897-09-2 ┆ 11        ┆ … ┆ ["Q652",  ┆ ["Q146953 ┆ null ┆ ["Q15183 │
# │           ┆           ┆ 6         ┆           ┆   ┆ "Q397",   ┆ 5", "Q193 ┆      ┆ 58", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q1321"]  ┆ 391"]     ┆      ┆ 15862152 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆      ┆ ", "Q1…  │
# │ Jan Pavel ┆ Q40219    ┆ 1912-10-1 ┆ 11        ┆ … ┆ ["Q652",  ┆ ["Q146953 ┆ null ┆ ["Q17544 │
# │ I.        ┆           ┆ 7         ┆           ┆   ┆ "Q397"]   ┆ 5",       ┆      ┆ 41", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "Q36180", ┆      ┆ 69789"]  │
# │           ┆           ┆           ┆           ┆   ┆           ┆ … "Q102…  ┆      ┆          │
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ ["Q809",  ┆ ["Q146953 ┆ null ┆ ["Q20996 │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆ "Q143", … ┆ 5",       ┆      ┆ 55", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q9091"]  ┆ "Q49757", ┆      ┆ 421431", │
# │           ┆           ┆           ┆           ┆   ┆           ┆ … "Q611…  ┆      ┆ … "Q8…   │
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q188",  ┆ ["Q146953 ┆ null ┆ ["Q15972 │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ "Q397", … ┆ 5", "Q242 ┆      ┆ 83", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q1321"]  ┆ 62594", … ┆      ┆ 421431", │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "Q…       ┆      ┆ … "Q6…   │
# │ František ┆ Q643907   ┆ 1936-12-1 ┆ 11        ┆ … ┆ ["Q1321", ┆ ["Q146953 ┆ null ┆ ["Q44226 │
# │           ┆           ┆ 7         ┆           ┆   ┆ "Q652", … ┆ 5", "Q593 ┆      ┆ 69", "Q6 │
# │           ┆           ┆           ┆           ┆   ┆ "Q1247932 ┆ 644", …   ┆      ┆ 66536"]  │
# │           ┆           ┆           ┆           ┆   ┆ "…        ┆ "Q48…     ┆      ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴──────┴──────────┘

# %%
df.filter(~pl.col('rodny_jazyk').is_null())
# Out:
# shape: (8, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬──────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ dalsi_jaz ┆ povolani  ┆ rady ┆ ucastnik │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ yky       ┆ ---       ┆ ---  ┆ ---      │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ list[str] ┆ null ┆ list[str │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆ list[str] ┆           ┆      ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪══════╪══════════╡
# │ Zefyrinus ┆ Q220      ┆ null      ┆ null      ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ null     │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ Marcellus ┆ Q220      ┆ 0255-01-0 ┆ 11        ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ null     │
# │ I.        ┆           ┆ 6         ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ Alexandr  ┆ Q738013   ┆ 1431-01-0 ┆ 11        ┆ … ┆ ["Q1321", ┆ ["Q250867 ┆ null ┆ ["Q23220 │
# │ VI.       ┆           ┆ 1         ┆           ┆   ┆ "Q7026",  ┆ ", "Q7834 ┆      ┆ 61", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q652"]   ┆ 465"]     ┆      ┆ 781741", │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆      ┆ … "Q1…   │
# │ Pius VI.  ┆ Q6662     ┆ 1717-12-2 ┆ 11        ┆ … ┆ ["Q397",  ┆ ["Q250867 ┆ null ┆ ["Q24082 │
# │           ┆           ┆ 5         ┆           ┆   ┆ "Q652"]   ┆ "]        ┆      ┆ 21"]     │
# │ Eusebius  ┆ Q1462     ┆ null      ┆ null      ┆ … ┆ null      ┆ ["Q250867 ┆ null ┆ null     │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "]        ┆      ┆          │
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q188",  ┆ ["Q146953 ┆ null ┆ ["Q15972 │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ "Q397", … ┆ 5", "Q242 ┆      ┆ 83", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q1321"]  ┆ 62594", … ┆      ┆ 421431", │
# │           ┆           ┆           ┆           ┆   ┆           ┆ "Q…       ┆      ┆ … "Q6…   │
# │ František ┆ Q643907   ┆ 1936-12-1 ┆ 11        ┆ … ┆ ["Q1321", ┆ ["Q146953 ┆ null ┆ ["Q44226 │
# │           ┆           ┆ 7         ┆           ┆   ┆ "Q652", … ┆ 5", "Q593 ┆      ┆ 69", "Q6 │
# │           ┆           ┆           ┆           ┆   ┆ "Q1247932 ┆ 644", …   ┆      ┆ 66536"]  │
# │           ┆           ┆           ┆           ┆   ┆ "…        ┆ "Q48…     ┆      ┆          │
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ ["Q809",  ┆ ["Q146953 ┆ null ┆ ["Q20996 │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆ "Q143", … ┆ 5",       ┆      ┆ 55", "Q1 │
# │           ┆           ┆           ┆           ┆   ┆ "Q9091"]  ┆ "Q49757", ┆      ┆ 421431", │
# │           ┆           ┆           ┆           ┆   ┆           ┆ … "Q611…  ┆      ┆ … "Q8…   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴──────┴──────────┘

# %%
try:
    os.makedirs('data_raw')
except:
    pass

# %%
nebyli_papezove = ['Cardinal Lamberto',"Jewish pope Andreas"]

# %%
df
# Out:
# shape: (267, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────┬───────────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ povolani  ┆ rady ┆ ucastnik  ┆ wikihesl │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ ---       ┆ ---  ┆ ---       ┆ a        │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ list[str] ┆ null ┆ list[str] ┆ ---      │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆           ┆      ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════╪═══════════╪══════════╡
# │ Cardinal  ┆ null      ┆ null      ┆ null      ┆ … ┆ ["Q42603" ┆ null ┆ null      ┆ ["enwiki │
# │ Lamberto  ┆           ┆           ┆           ┆   ┆ ]         ┆      ┆           ┆ ", "fawi │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ ki", …   │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "plwiki… │
# │ Jewish    ┆ null      ┆ null      ┆ null      ┆ … ┆ ["Q831474 ┆ null ┆ null      ┆ ["arwiki │
# │ pope      ┆           ┆           ┆           ┆   ┆ "]        ┆      ┆           ┆ ", "dewi │
# │ Andreas   ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ ki", …   │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "ruwiki… │
# │ svatý     ┆ Q501773   ┆ 0001-00-0 ┆ 9         ┆ … ┆ ["Q831474 ┆ null ┆ null      ┆ ["acewik │
# │ Petr      ┆           ┆ 0         ┆           ┆   ┆ ", "Q3314 ┆      ┆           ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 32",      ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q61164…  ┆      ┆           ┆ "zhwik…  │
# │ Linus     ┆ Q1273     ┆ 0010-01-0 ┆ 9         ┆ … ┆ ["Q105200 ┆ null ┆ null      ┆ ["afwiki │
# │           ┆           ┆ 1         ┆           ┆   ┆ 223"]     ┆      ┆           ┆ ", "alsw │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "zhwik…  │
# │ Anaklét   ┆ Q220      ┆ 0025-00-0 ┆ 9         ┆ … ┆ ["Q250867 ┆ null ┆ null      ┆ ["afwiki │
# │           ┆           ┆ 0         ┆           ┆   ┆ "]        ┆      ┆           ┆ ", "alsw │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "zhwik…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …    ┆ …         ┆ …        │
# │ Pavel VI. ┆ Q104074   ┆ 1897-09-2 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q151835 ┆ ["acewik │
# │           ┆           ┆ 6         ┆           ┆   ┆ 5", "Q193 ┆      ┆ 8", "Q115 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 391"]     ┆      ┆ 862152",  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆ "Q1…      ┆ "zhwik…  │
# │ Jan Pavel ┆ Q40219    ┆ 1912-10-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q175444 ┆ ["acewik │
# │ I.        ┆           ┆ 7         ┆           ┆   ┆ 5",       ┆      ┆ 1", "Q169 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ "Q36180", ┆      ┆ 789"]     ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ … "Q102…  ┆      ┆           ┆ "zhwik…  │
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q209965 ┆ ["acewik │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆ 5",       ┆      ┆ 5", "Q142 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ "Q49757", ┆      ┆ 1431", …  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ … "Q611…  ┆      ┆ "Q8…      ┆ "zhwik…  │
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q159728 ┆ ["acewik │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ 5", "Q242 ┆      ┆ 3", "Q142 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 62594", … ┆      ┆ 1431", …  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q…       ┆      ┆ "Q6…      ┆ "zhwik…  │
# │ František ┆ Q643907   ┆ 1936-12-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q442266 ┆ ["acewik │
# │           ┆           ┆ 7         ┆           ┆   ┆ 5", "Q593 ┆      ┆ 9", "Q666 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 644", …   ┆      ┆ 536"]     ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q48…     ┆      ┆           ┆ "zhwik…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────┴───────────┴──────────┘

# %%
sloupce_s_daty = [col for col in df.columns if "datum" in col or "zacatek" in col or "konec" in col]

# %%
df.filter(pl.col("jmeno") == "Benedikt XVI.")
# Out:
# shape: (1, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────┬───────────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ povolani  ┆ rady ┆ ucastnik  ┆ wikihesl │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ ---       ┆ ---  ┆ ---       ┆ a        │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ list[str] ┆ null ┆ list[str] ┆ ---      │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆           ┆      ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════╪═══════════╪══════════╡
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q159728 ┆ ["acewik │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ 5", "Q242 ┆      ┆ 3", "Q142 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 62594", … ┆      ┆ 1431", …  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q…       ┆      ┆ "Q6…      ┆ "zhwik…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────┴───────────┴──────────┘

# %%
df.with_columns(pl.col(sloupce_s_daty).str.replace_all('-00','-01').str.to_date(format="%Y-%m-%d")).with_columns((pl.col('pontifikat_konec') - pl.col('pontifikat_zacatek')).alias('delka_pontifikatu')).sort(by="delka_pontifikatu")
# Out:
# shape: (267, 19)
# ┌───────────┬───────────┬───────────┬───────────┬───┬──────┬───────────┬───────────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ rady ┆ ucastnik  ┆ wikihesla ┆ delka_po │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ ---  ┆ ---       ┆ ---       ┆ ntifikat │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ null ┆ list[str] ┆ list[str] ┆ u        │
# │           ┆ str       ┆ date      ┆ i64       ┆   ┆      ┆           ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆           ┆ duration │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆           ┆ [ms]     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪══════╪═══════════╪═══════════╪══════════╡
# │ Cardinal  ┆ null      ┆ null      ┆ null      ┆ … ┆ null ┆ null      ┆ ["enwiki" ┆ null     │
# │ Lamberto  ┆           ┆           ┆           ┆   ┆      ┆           ┆ ,         ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "fawiki", ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ …         ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "plwiki…  ┆          │
# │ Jewish    ┆ null      ┆ null      ┆ null      ┆ … ┆ null ┆ null      ┆ ["arwiki" ┆ null     │
# │ pope      ┆           ┆           ┆           ┆   ┆      ┆           ┆ ,         ┆          │
# │ Andreas   ┆           ┆           ┆           ┆   ┆      ┆           ┆ "dewiki", ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ …         ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "ruwiki…  ┆          │
# │ Štěpán    ┆ Q220      ┆ 0700-01-0 ┆ 7         ┆ … ┆ null ┆ null      ┆ ["afwiki" ┆ 3d       │
# │ II.       ┆           ┆ 1         ┆           ┆   ┆      ┆           ┆ , "alswik ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ i", …     ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwik…   ┆          │
# │ Celestýn  ┆ Q490      ┆ null      ┆ null      ┆ … ┆ null ┆ null      ┆ ["afwiki" ┆ 9d       │
# │ IV.       ┆           ┆           ┆           ┆   ┆      ┆           ┆ , "alswik ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ i", …     ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwik…   ┆          │
# │ Marcellus ┆ Q83113    ┆ 1501-05-0 ┆ 11        ┆ … ┆ null ┆ ["Q329760 ┆ ["afwiki" ┆ 12d      │
# │ II.       ┆           ┆ 6         ┆           ┆   ┆      ┆ 5", "Q178 ┆ ,         ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆ 1743"]    ┆ "arwiki", ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ …         ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwiki…  ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …    ┆ …         ┆ …         ┆ …        │
# │ Pius VI.  ┆ Q6662     ┆ 1717-12-2 ┆ 11        ┆ … ┆ null ┆ ["Q240822 ┆ ["afwiki" ┆ 8961d    │
# │           ┆           ┆ 5         ┆           ┆   ┆      ┆ 1"]       ┆ , "alswik ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ i", …     ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwik…   ┆          │
# │ Lev XIII. ┆ Q242000   ┆ 1810-03-0 ┆ 11        ┆ … ┆ null ┆ ["Q374575 ┆ ["afwiki" ┆ 9280d    │
# │           ┆           ┆ 2         ┆           ┆   ┆      ┆ ", "Q1908 ┆ , "alswik ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆ 57"]      ┆ i", …     ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwik…   ┆          │
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ null ┆ ["Q209965 ┆ ["acewiki ┆ 9665d    │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆      ┆ 5", "Q142 ┆ ",        ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆ 1431", …  ┆ "afwiki", ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆ "Q8…      ┆ … "zhwik… ┆          │
# │ Pius IX.  ┆ Q124925   ┆ 1792-05-1 ┆ 11        ┆ … ┆ null ┆ ["Q954152 ┆ ["afwiki" ┆ 11559d   │
# │           ┆           ┆ 3         ┆           ┆   ┆      ┆ ", "Q1908 ┆ , "alswik ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆ 57"]      ┆ i", …     ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "zhwik…   ┆          │
# │ svatý     ┆ Q501773   ┆ 0001-01-0 ┆ 9         ┆ … ┆ null ┆ null      ┆ ["acewiki ┆ 12418d   │
# │ Petr      ┆           ┆ 1         ┆           ┆   ┆      ┆           ┆ ",        ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ "afwiki", ┆          │
# │           ┆           ┆           ┆           ┆   ┆      ┆           ┆ … "zhwik… ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴──────┴───────────┴───────────┴──────────┘

# %%
df.with_columns(pl.col("wikihesla").map_elements(len)).sort(by="wikihesla",descending=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_5468\2957041126.py:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df.with_columns(pl.col("wikihesla").map_elements(len)).sort(by="wikihesla",descending=True)
# shape: (267, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────┬───────────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ povolani  ┆ rady ┆ ucastnik  ┆ wikihesl │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ ---       ┆ ---  ┆ ---       ┆ a        │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ list[str] ┆ null ┆ list[str] ┆ ---      │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆           ┆      ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════╪═══════════╪══════════╡
# │ František ┆ Q643907   ┆ 1936-12-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q442266 ┆ 171      │
# │           ┆           ┆ 7         ┆           ┆   ┆ 5", "Q593 ┆      ┆ 9", "Q666 ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 644", …   ┆      ┆ 536"]     ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Q48…     ┆      ┆           ┆          │
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q159728 ┆ 149      │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ 5", "Q242 ┆      ┆ 3", "Q142 ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 62594", … ┆      ┆ 1431", …  ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Q…       ┆      ┆ "Q6…      ┆          │
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q209965 ┆ 146      │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆ 5",       ┆      ┆ 5", "Q142 ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Q49757", ┆      ┆ 1431", …  ┆          │
# │           ┆           ┆           ┆           ┆   ┆ … "Q611…  ┆      ┆ "Q8…      ┆          │
# │ svatý     ┆ Q501773   ┆ 0001-00-0 ┆ 9         ┆ … ┆ ["Q831474 ┆ null ┆ null      ┆ 129      │
# │ Petr      ┆           ┆ 0         ┆           ┆   ┆ ", "Q3314 ┆      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 32",      ┆      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Q61164…  ┆      ┆           ┆          │
# │ Jan       ┆ Q101616   ┆ 1881-11-2 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q520640 ┆ 110      │
# │ XXIII.    ┆           ┆ 5         ┆           ┆   ┆ 5", "Q783 ┆      ┆ ", "Q1697 ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 4465",    ┆      ┆ 89"]      ┆          │
# │           ┆           ┆           ┆           ┆   ┆ "Q102…    ┆      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …    ┆ …         ┆ …        │
# │ Martin    ┆ Q605051   ┆ 1220-03-2 ┆ 11        ┆ … ┆ ["Q193391 ┆ null ┆ null      ┆ 63       │
# │ IV.       ┆           ┆ 7         ┆           ┆   ┆ ", "Q2508 ┆      ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆ 67"]      ┆      ┆           ┆          │
# │ Honorius  ┆ Q220      ┆ 1210-00-0 ┆ 9         ┆ … ┆ ["Q250867 ┆ null ┆ ["Q146230 ┆ 63       │
# │ IV.       ┆           ┆ 0         ┆           ┆   ┆ "]        ┆      ┆ 82", "Q26 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆ 22938",   ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆ "Q37…     ┆          │
# │ Štěpán    ┆ Q220      ┆ 0700-00-0 ┆ 7         ┆ … ┆ ["Q250867 ┆ null ┆ null      ┆ 58       │
# │ II.       ┆           ┆ 0         ┆           ┆   ┆ "]        ┆      ┆           ┆          │
# │ Jewish    ┆ null      ┆ null      ┆ null      ┆ … ┆ ["Q831474 ┆ null ┆ null      ┆ 6        │
# │ pope      ┆           ┆           ┆           ┆   ┆ "]        ┆      ┆           ┆          │
# │ Andreas   ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆          │
# │ Cardinal  ┆ null      ┆ null      ┆ null      ┆ … ┆ ["Q42603" ┆ null ┆ null      ┆ 4        │
# │ Lamberto  ┆           ┆           ┆           ┆   ┆ ]         ┆      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────┴───────────┴──────────┘

# %%
df.with_columns(pl.col("dalsi_jazyky").map_elements(len)).drop_nulls(subset="dalsi_jazyky").sort(by="dalsi_jazyky",descending=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_5468\3552235177.py:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df.with_columns(pl.col("dalsi_jazyky").map_elements(len)).drop_nulls(subset="dalsi_jazyky").sort(by="dalsi_jazyky",descending=True)
# shape: (177, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────┬───────────┬──────────┐
# │ jmeno     ┆ narozeni_ ┆ narozeni_ ┆ narozeni_ ┆ … ┆ povolani  ┆ rady ┆ ucastnik  ┆ wikihesl │
# │ ---       ┆ misto     ┆ datum     ┆ presnost  ┆   ┆ ---       ┆ ---  ┆ ---       ┆ a        │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ list[str] ┆ null ┆ list[str] ┆ ---      │
# │           ┆ str       ┆ str       ┆ i64       ┆   ┆           ┆      ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════╪═══════════╪══════════╡
# │ Jan Pavel ┆ Q212856   ┆ 1920-05-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q209965 ┆ ["acewik │
# │ II.       ┆           ┆ 8         ┆           ┆   ┆ 5",       ┆      ┆ 5", "Q142 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ "Q49757", ┆      ┆ 1431", …  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ … "Q611…  ┆      ┆ "Q8…      ┆ "zhwik…  │
# │ František ┆ Q643907   ┆ 1936-12-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q442266 ┆ ["acewik │
# │           ┆           ┆ 7         ┆           ┆   ┆ 5", "Q593 ┆      ┆ 9", "Q666 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 644", …   ┆      ┆ 536"]     ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q48…     ┆      ┆           ┆ "zhwik…  │
# │ Pius XII. ┆ Q220      ┆ 1876-03-0 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q137623 ┆ ["acewik │
# │           ┆           ┆ 2         ┆           ┆   ┆ 5", "Q611 ┆      ┆ 4"]       ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 644"]     ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "zhwik…  │
# │ Benedikt  ┆ Q2348968  ┆ 1927-04-1 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q159728 ┆ ["acewik │
# │ XVI.      ┆           ┆ 6         ┆           ┆   ┆ 5", "Q242 ┆      ┆ 3", "Q142 ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 62594", … ┆      ┆ 1431", …  ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q…       ┆      ┆ "Q6…      ┆ "zhwik…  │
# │ Klement   ┆ Q243024   ┆ 1190-11-2 ┆ 11        ┆ … ┆ ["Q82955" ┆ null ┆ null      ┆ ["afwiki │
# │ IV.       ┆           ┆ 3         ┆           ┆   ┆ , "Q25086 ┆      ┆           ┆ ", "anwi │
# │           ┆           ┆           ┆           ┆   ┆ 7", …     ┆      ┆           ┆ ki", …   │
# │           ┆           ┆           ┆           ┆   ┆ "Q6116…   ┆      ┆           ┆ "zhwiki… │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …    ┆ …         ┆ …        │
# │ Alexandr  ┆ Q641      ┆ 1610-04-2 ┆ 11        ┆ … ┆ ["Q250867 ┆ null ┆ ["Q236516 ┆ ["afwiki │
# │ VIII.     ┆           ┆ 2         ┆           ┆   ┆ ", "Q6116 ┆      ┆ 6", "Q124 ┆ ", "anwi │
# │           ┆           ┆           ┆           ┆   ┆ 44"]      ┆      ┆ 4450", …  ┆ ki", …   │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆ "Q2…      ┆ "zhwiki… │
# │ Klement   ┆ Q2044     ┆ 1652-04-0 ┆ 11        ┆ … ┆ ["Q250867 ┆ null ┆ ["Q260110 ┆ ["afwiki │
# │ XII.      ┆           ┆ 7         ┆           ┆   ┆ ", "Q6116 ┆      ┆ 4", "Q158 ┆ ", "anwi │
# │           ┆           ┆           ┆           ┆   ┆ 44"]      ┆      ┆ 0637",    ┆ ki", …   │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆ "Q238…    ┆ "zhwiki… │
# │ Pius VII. ┆ Q6662     ┆ 1742-08-1 ┆ 11        ┆ … ┆ ["Q250867 ┆ null ┆ ["Q231366 ┆ ["afwiki │
# │           ┆           ┆ 4         ┆           ┆   ┆ ", "Q6116 ┆      ┆ 1"]       ┆ ", "alsw │
# │           ┆           ┆           ┆           ┆   ┆ 44"]      ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "zhwik…  │
# │ Benedikt  ┆ Q833271   ┆ 1854-11-2 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q762715 ┆ ["acewik │
# │ XV.       ┆           ┆ 1         ┆           ┆   ┆ 5", "Q611 ┆      ┆ "]        ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 644"]     ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆           ┆      ┆           ┆ "zhwik…  │
# │ Pius XI.  ┆ Q40416    ┆ 1857-05-3 ┆ 11        ┆ … ┆ ["Q146953 ┆ null ┆ ["Q993705 ┆ ["acewik │
# │           ┆           ┆ 1         ┆           ┆   ┆ 5", "Q182 ┆      ┆ "]        ┆ i", "afw │
# │           ┆           ┆           ┆           ┆   ┆ 436", …   ┆      ┆           ┆ iki", …  │
# │           ┆           ┆           ┆           ┆   ┆ "Q61…     ┆      ┆           ┆ "zhwik…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────┴───────────┴──────────┘

# %%
df_final = df.with_columns(pl.col(sloupce_s_daty).str.replace_all('-00','-01').str.to_date(format="%Y-%m-%d")).filter(~pl.col('jmeno').is_in(nebyli_papezove))

# %%
df_final.write_json('data_raw/papezstvo_raw.json')
df_final.write_parquet('data_raw/papezstvo_raw.parquet', use_pyarrow=True)
